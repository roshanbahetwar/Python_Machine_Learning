# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv")

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df1 = df.groupby('genre')

# %%
df1.get_group('Crime')
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df2 = df.groupby('content_rating')

# %%
df2.get_group('R')
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df1.get_group('Action')
# Out:
#      star_rating                                            title  \
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                        Star Wars
# 20           8.7                                       The Matrix
# ..           ...                                              ...
# 918          7.5                                   Running Scared
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating   genre  duration  \
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 12              PG  Action       124
# ...

# %%
df.groupby(['content_rating','genre']).get_group(('R','Action'))
# Out:
#      star_rating                       title content_rating   genre  duration  \
# 20           8.7                  The Matrix              R  Action       136
# 36           8.6         Saving Private Ryan              R  Action       169
# 44           8.5                   Gladiator              R  Action       155
# 45           8.5  Terminator 2: Judgment Day              R  Action       137
# 75           8.4                      Aliens              R  Action       137
# ..           ...                         ...            ...     ...       ...
# 885          7.5                Total Recall              R  Action       113
# 906          7.5                      Looper              R  Action       119
# 918          7.5              Running Scared              R  Action       122
# 963          7.4             La Femme Nikita              R  Action       118
# 967          7.4                    The Rock              R  Action       136
#
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df3 = df.groupby('content_rating')

# %%
df3.get_group('PG')
# Out:
#      star_rating                                           title  \
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 30           8.6                                   Spirited Away
# 32           8.6                                      Casablanca
# 37           8.6                         Raiders of the Lost Ark
# ..           ...                                             ...
# 956          7.4                        Manhattan Murder Mystery
# 962          7.4                              Driving Miss Daisy
# 974          7.4                                         Tootsie
# 975          7.4                     Back to the Future Part III
# 977          7.4                                     Poltergeist
#
#     content_rating      genre  duration  \
# 12              PG     Action       124
# 19              PG     Action       121
# 30              PG  Animation       125
# ...

# %%
df.groupby(['content_rating','genre']).get_group(('R','Action'))
# Out:
#      star_rating                       title content_rating   genre  duration  \
# 20           8.7                  The Matrix              R  Action       136
# 36           8.6         Saving Private Ryan              R  Action       169
# 44           8.5                   Gladiator              R  Action       155
# 45           8.5  Terminator 2: Judgment Day              R  Action       137
# 75           8.4                      Aliens              R  Action       137
# ..           ...                         ...            ...     ...       ...
# 885          7.5                Total Recall              R  Action       113
# 906          7.5                      Looper              R  Action       119
# 918          7.5              Running Scared              R  Action       122
# 963          7.4             La Femme Nikita              R  Action       118
# 967          7.4                    The Rock              R  Action       136
#
# ...

# %%
df[(df['content_rating']=='R') & (df['genre']=='Crime')]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
df[(df['genre']=='Action') & (df['content_rating']=='R')]    #'Action' Record from Genre and 'R record from content_rating'
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 969          7.4                              Law Abiding Citizen
# 970          7.4                                      Wonder Boys
# 971          7.4                               Death at a Funeral
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
df[(df['genre']=='Crime')|(df['genre']=='Action')]   # 'Crime' & 'Action' record from genre------use OR symbol
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 969          7.4                              Law Abiding Citizen
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %%
df[df['star_rating'] == df['star_rating'].max()]    # find max value of star_rating
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
df[df['duration'] == df['duration'].max()]    # find max value of duration
# Out:
#      star_rating   title content_rating  genre  duration  \
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
df[df['duration'] == df['duration'].min()]    # find min value of duration
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
#
#                                            actors_list
# 389  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...

# %%
df[(df['duration'] == df['duration'].max()) | (df['duration'] == df['duration'].min())]   # max and min record of 'duration'
# Out:
#      star_rating   title content_rating  genre  duration  \
# 389          8.0  Freaks        UNRATED  Drama        64
# 476          7.8  Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 389  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
df4 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\Pune_SmartCity_Test_Dataset.csv")

# %%
df5 = df4.dropna()

# %%
df5.describe()
# Out:
#            HUMIDITY         LIGHT   NO_MAX   NO_MIN       NO2_MAX  \
# count  82689.000000  82689.000000  82689.0  82689.0  82689.000000
# mean      63.038801   1899.786174      0.0      0.0     72.779233
# std       21.988782   5305.817688      0.0      0.0     38.608931
# min       10.166000      0.094000      0.0      0.0      0.000000
# 25%       47.456000      2.263000      0.0      0.0     46.000000
# 50%       68.458000    192.252000      0.0      0.0     78.000000
# 75%       81.210000   1910.547000      0.0      0.0     97.000000
# max       97.359000  64811.321000      0.0      0.0    316.000000
#
#             NO2_MIN     OZONE_MAX     OZONE_MIN      PM10_MAX      PM10_MIN  \
# count  82689.000000  82689.000000  82689.000000  82689.000000  82689.000000
# mean      63.147553     16.481019      4.141155     19.502316     14.974979
# std       34.493461     27.172834     17.377702     12.283616     10.864559
# ...

# %%
df4
# Out:
#                                             NAME  HUMIDITY     LIGHT  NO_MAX  \
# 0                                BopadiSquare_65    19.995  3762.914       0
# 1                          Karve Statue Square_5    20.730   529.245       0
# 2                           Lullanagar_Square_14    17.387   693.375       0
# 3                            Hadapsar_Gadital_01    18.725   723.631       0
# 4                      PMPML_Bus_Depot_Deccan_15    20.622   816.476       0
# ...                                          ...       ...       ...     ...
# 103200                       Hadapsar_Gadital_01    73.903  3388.676       0
# 103201  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984  2530.419       0
# 103202                      Lullanagar_Square_14    74.412  1831.434       0
# 103203                     Karve Statue Square_5    75.912   291.391       0
# 103204                   Pune Railway Station_28    72.648  3664.177       0
#
# ...

# %%
df4[df4['HUMIDITY'] == df4['HUMIDITY'].max()]
# Out:
#                           NAME  HUMIDITY  LIGHT  NO_MAX  NO_MIN  NO2_MAX  \
# 56682  Goodluck Square_Cafe_23    97.359  1.335       0       0     26.0
# 56690  Goodluck Square_Cafe_23    97.359  1.375       0       0     26.0
# 56697  Goodluck Square_Cafe_23    97.359  1.290       0       0     26.0
# 56704  Goodluck Square_Cafe_23    97.359  1.184       0       0     26.0
#
#        NO2_MIN  OZONE_MAX  OZONE_MIN  PM10_MAX  ...  CO2_MIN  SOUND  \
# 56682     13.0       13.0        2.0       3.0  ...      0.0  65.27
# 56690     13.0       13.0        2.0       3.0  ...      0.0  65.27
# 56697     13.0       13.0        2.0       3.0  ...      0.0  65.27
# 56704     13.0       13.0        2.0       3.0  ...      0.0  65.27
#
#        TEMPRATURE_MAX  TEMPRATURE_MIN  UV_MAX  UV_MIN  AIR_PRESSURE  \
# 56682            29.0            23.0     0.7     0.2         0.931
# 56690            29.0            23.0     0.7     0.2         0.931
# ...

# %%
df4[(df4['HUMIDITY']==df4['HUMIDITY'].max())|(df4['HUMIDITY']== df4['HUMIDITY'].min())]  # fetch min and max value of humidity
# Out:
#                           NAME  HUMIDITY    LIGHT  NO_MAX  NO_MIN  NO2_MAX  \
# 7980      Lullanagar_Square_14    10.166  627.613       0       0    108.0
# 7993      Lullanagar_Square_14    10.166  487.045       0       0    108.0
# 8003      Lullanagar_Square_14    10.166  341.820       0       0    108.0
# 8006      Lullanagar_Square_14    10.166  180.337       0       0    108.0
# 56682  Goodluck Square_Cafe_23    97.359    1.335       0       0     26.0
# 56690  Goodluck Square_Cafe_23    97.359    1.375       0       0     26.0
# 56697  Goodluck Square_Cafe_23    97.359    1.290       0       0     26.0
# 56704  Goodluck Square_Cafe_23    97.359    1.184       0       0     26.0
#
#        NO2_MIN  OZONE_MAX  OZONE_MIN  PM10_MAX  ...  CO2_MIN   SOUND  \
# 7980      71.0       72.0        0.0      39.0  ...     16.0  63.661
# 7993      71.0       72.0        0.0      39.0  ...     16.0  63.661
# 8003      71.0       72.0        0.0      39.0  ...     16.0  63.661
# ...

# %%
df4[(df4['HUMIDITY']==df4['HUMIDITY'].max())|(df4['HUMIDITY']== df4['HUMIDITY'].min())]['HUMIDITY'].value_counts() # fetch min and max value of humidity and their counts
# Out:
# 10.166    4
# 97.359    4
# Name: HUMIDITY, dtype: int64

# %%
df4
# Out:
#                                             NAME  HUMIDITY     LIGHT  NO_MAX  \
# 0                                BopadiSquare_65    19.995  3762.914       0
# 1                          Karve Statue Square_5    20.730   529.245       0
# 2                           Lullanagar_Square_14    17.387   693.375       0
# 3                            Hadapsar_Gadital_01    18.725   723.631       0
# 4                      PMPML_Bus_Depot_Deccan_15    20.622   816.476       0
# ...                                          ...       ...       ...     ...
# 103200                       Hadapsar_Gadital_01    73.903  3388.676       0
# 103201  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984  2530.419       0
# 103202                      Lullanagar_Square_14    74.412  1831.434       0
# 103203                     Karve Statue Square_5    75.912   291.391       0
# 103204                   Pune Railway Station_28    72.648  3664.177       0
#
# ...

# %%
df.groupby('genre').agg(['max','count'])
# Out:
# C:\Users\Roshan B\AppData\Local\Temp\ipykernel_14552\1256445960.py:1: FutureWarning: ['content_rating'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('genre').agg(['max','count'])
#           star_rating                                      title        \
#                   max count                                  max count
# genre
# Action            9.0   136                              Yojimbo   136
# Adventure         8.9    75                            True Grit    75
# Animation         8.6    62                       Wreck-It Ralph    62
# Biography         8.9    77                        Walk the Line    77
# Comedy            8.6   156                           Zombieland   156
# Crime             9.3   124                               Zodiac   124
# Drama             8.9   278                                 Zulu   278
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
print(df['actors_list'].to_dict()[0])                    # to check full of content and convert dict and fetch single one
# Out:
# [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']

# %%
df[df['title'].str.contains('God')]
# Out:
#      star_rating                      title content_rating      genre  \
# 1            9.2              The Godfather              R      Crime
# 2            9.1     The Godfather: Part II              R      Crime
# 21           8.7                City of God              R      Crime
# 328          8.0  Aguirre, the Wrath of God      NOT RATED  Adventure
# 711          7.6    The Godfather: Part III              R      Crime
#
#      duration                                        actors_list
# 1         175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2         200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 21        130  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# 328        93   [u'Klaus Kinski', u'Ruy Guerra', u'Helena Rojo']
# 711       162    [u'Al Pacino', u'Diane Keaton', u'Andy Garcia']

# %%
df[df.apply(lambda row: 'Godfather' in row['title'], axis=1)]
# Out:
#      star_rating                    title content_rating  genre  duration  \
# 1            9.2            The Godfather              R  Crime       175
# 2            9.1   The Godfather: Part II              R  Crime       200
# 711          7.6  The Godfather: Part III              R  Crime       162
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 711    [u'Al Pacino', u'Diane Keaton', u'Andy Garcia']

# %%
df['new'] = df['title'].apply(lambda x: x in 'God')

# %%
df.drop('new',axis=1,inplace = True)

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df[df['title'].str.contains('God')]
# Out:
#      star_rating                      title content_rating      genre  \
# 1            9.2              The Godfather              R      Crime
# 2            9.1     The Godfather: Part II              R      Crime
# 21           8.7                City of God              R      Crime
# 328          8.0  Aguirre, the Wrath of God      NOT RATED  Adventure
# 711          7.6    The Godfather: Part III              R      Crime
#
#      duration                                        actors_list
# 1         175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2         200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 21        130  [u'Alexandre Rodrigues', u'Matheus Nachtergael...
# 328        93   [u'Klaus Kinski', u'Ruy Guerra', u'Helena Rojo']
# 711       162    [u'Al Pacino', u'Diane Keaton', u'Andy Garcia']
