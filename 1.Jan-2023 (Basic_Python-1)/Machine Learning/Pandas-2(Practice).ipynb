# %%
import pandas as pd

# %%
emp_list = [(1,'Roshan','17/10/1993','Ngpur'),
           (2,'Rakesh','15/3/1996','Tumsar'),
           (3,'Ajay','15/08/1998','Pune'),
           (4,'Amit','11/10/1947','Mumbai'),
           (5,'Akshay','14/05/1670','Gujrat')]

# %%
df = pd.DataFrame(emp_list,columns=['Id','Name','DOB','City'])

# %%
df
# Out:
#    Id    Name         DOB    City
# 0   1  Roshan  17/10/1993   Ngpur
# 1   2  Rakesh   15/3/1996  Tumsar
# 2   3    Ajay  15/08/1998    Pune
# 3   4    Amit  11/10/1947  Mumbai
# 4   5  Akshay  14/05/1670  Gujrat

# %%
df.to_csv('emp_list')

# %%
e_dict = [{'Name':'A','Salary':65000,'Designation':'AE','City':'Mumbai'},
         {'Name':'B','Salary':75000,'Designation':'JE','City':'Nagpur'},
         {'Name':'C','Salary':55000,'Designation':'GET','City':'Banglore'},
         {'Name':'D','Salary':49000,'Designation':'Manager','City':'Pune'},
         {'Name':'E','Salary':40000,'Designation':'HOD','City':'Kolkata'},]

# %%
df1 = pd.DataFrame(e_dict)

# %%
df1
# Out:
#   Name  Salary Designation      City
# 0    A   65000          AE    Mumbai
# 1    B   75000          JE    Nagpur
# 2    C   55000         GET  Banglore
# 3    D   49000     Manager      Pune
# 4    E   40000         HOD   Kolkata

# %%
df2 = pd.read_html('https://www.worldometers.info/world-population/georgia-population/')[1]  # web scrapping-Read Html page and fetch 2nd table by index 1.

# %%
df2
# Out:
#     Year  Population Yearly % Change  Yearly  Change  Migrants (net)  \
# 0   2020     3989167         -0.19 %           -7598          -10000
# 1   2019     3996765         -0.15 %           -6177          -10000
# 2   2018     4002942         -0.14 %           -5774          -10000
# 3   2017     4008716         -0.17 %           -6734          -10000
# 4   2016     4015450         -0.22 %           -8733          -10000
# 5   2015     4024183         -0.37 %          -14983          -19068
# 6   2010     4099099         -0.53 %          -22214          -23962
# 7   2005     4210168         -0.71 %          -30404          -29667
# 8   2000     4362187         -2.60 %         -122815         -130719
# 9   1995     4976260         -1.66 %          -86828         -118371
# 10  1990     5410399          0.75 %           39789           -8732
# 11  1985     5211454          0.76 %           38724           -9565
# 12  1980     5017833          0.58 %           28839          -19089
# ...

# %%
df2.to_excel('Georgia_Population.xlsx')

# %%
df3 = pd.read_excel('Georgia_Population.xlsx')

# %%
df3
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly  Change  \
# 0            0  2020     3989167         -0.19 %           -7598
# 1            1  2019     3996765         -0.15 %           -6177
# 2            2  2018     4002942         -0.14 %           -5774
# 3            3  2017     4008716         -0.17 %           -6734
# 4            4  2016     4015450         -0.22 %           -8733
# 5            5  2015     4024183         -0.37 %          -14983
# 6            6  2010     4099099         -0.53 %          -22214
# 7            7  2005     4210168         -0.71 %          -30404
# 8            8  2000     4362187         -2.60 %         -122815
# 9            9  1995     4976260         -1.66 %          -86828
# 10          10  1990     5410399          0.75 %           39789
# 11          11  1985     5211454          0.76 %           38724
# 12          12  1980     5017833          0.58 %           28839
# ...

# %%
df4 = pd.read_html('https://www.worldometers.info/world-population/india-population/')[1]

# %%
df4
# Out:
#     Year  Population Yearly % Change  Yearly  Change  Migrants (net)  \
# 0   2020  1380004385          0.99 %        13586631         -532687
# 1   2019  1366417754          1.02 %        13775474         -532687
# 2   2018  1352642280          1.04 %        13965495         -532687
# 3   2017  1338676785          1.07 %        14159536         -532687
# 4   2016  1324517249          1.10 %        14364846         -532687
# 5   2015  1310152403          1.20 %        15174247         -470015
# 6   2010  1234281170          1.47 %        17334249         -531169
# 7   2005  1147609927          1.67 %        18206876         -377797
# 8   2000  1056575549          1.85 %        18530592         -136514
# 9   1995   963922588          1.99 %        18128958         -110590
# 10  1990   873277798          2.17 %        17783558            9030
# 11  1985   784360008          2.33 %        17081433          115942
# 12  1980   698952844          2.32 %        15169989          222247
# ...

# %%
df4.to_csv('India_Population')

# %%
df5 = pd.read_csv('India_Population')

# %%
df6 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\Spotify_Youtube.csv")

# %%
df6
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
df6.to_excel('Tracks.xlsx')
# Out:
# C:\Users\Roshan B\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:1170: UserWarning: Ignoring URL 'https://www.youtube.com/watch?v=ME9XpnQiU-8
# And%20I%20heard%20as%20it%20were%20the%20noise%20of%20thunder%20
# One%20of%20the%20four%20beasts%20saying%20come%20and%20see%20and%20I%20saw
# And%20behold%20a%20white%20horse
#
# There's%20a%20man%20going%20around%20taking%20names%20
# And%20he%20decides%20who%20to%20free%20and%20who%20to%20blame
# Everybody%20won't%20be%20treated%20all%20the%20same
# There'll%20be%20a%20golden%20ladder%20reaching%20down
# When%20the%20Man%20comes%20around
#
# The%20hairs%20on%20your%20arm%20will%20stand%20up%20
# At%20the%20terror%20in%20each%20sip%20and%20in%20each%20sup
# Will%20you%20partake%20of%20that%20last%20offered%20cup?
# Or%20disappear%20into%20the%20potter's%20ground
# When%20the%20Man%20comes%20around
#
# Hear%20the%20trumpets,%20hear%20the%20pipers
# One%20hundred%20million%20angels%20singing
# ...

# %%
df7 = pd.read_excel(r"C:\Users\Roshan B\Desktop\ML\Dataset\Tracks.xlsx")

# %%
df7.value_counts('Artist')
# Out:
# Artist
# $NOT                 10
# Outkast              10
# No Te Va Gustar      10
# No Doubt             10
# Nko                  10
#                      ..
# NewJeans              6
# Shubh                 6
# Jimin                 3
# Bootie Brown          1
# Stars Music Chile     1
# Length: 2079, dtype: int64

# %%
df7.shape
# Out:
# (20718, 29)

# %%
df7
# Out:
#        Unnamed: 0.1  Unnamed: 0       Artist  \
# 0                 0           0     Gorillaz
# 1                 1           1     Gorillaz
# 2                 2           2     Gorillaz
# 3                 3           3     Gorillaz
# 4                 4           4     Gorillaz
# ...             ...         ...          ...
# 20713         20713       20713  SICK LEGEND
# 20714         20714       20714  SICK LEGEND
# 20715         20715       20715  SICK LEGEND
# 20716         20716       20716  SICK LEGEND
# 20717         20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# ...

# %%
df7.Track
# Out:
# 0                                       Feel Good Inc.
# 1                                      Rhinestone Eyes
# 2        New Gold (feat. Tame Impala and Bootie Brown)
# 3                                   On Melancholy Hill
# 4                                       Clint Eastwood
#                              ...
# 20713                             JUST DANCE HARDSTYLE
# 20714                   SET FIRE TO THE RAIN HARDSTYLE
# 20715                        OUTSIDE HARDSTYLE SPED UP
# 20716                              ONLY GIRL HARDSTYLE
# 20717                               MISS YOU HARDSTYLE
# Name: Track, Length: 20718, dtype: object

# %%
df7.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album',
#        'Album_type', 'Uri', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Url_youtube', 'Title', 'Channel',
#        'Views', 'Likes', 'Comments', 'Description', 'Licensed',
#        'official_video', 'Stream'],
#       dtype='object')

# %%
df7[['Unnamed: 0.1','Track','Album','Energy','Channel']]
# Out:
#        Unnamed: 0.1                                          Track  \
# 0                 0                                 Feel Good Inc.
# 1                 1                                Rhinestone Eyes
# 2                 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                 3                             On Melancholy Hill
# 4                 4                                 Clint Eastwood
# ...             ...                                            ...
# 20713         20713                           JUST DANCE HARDSTYLE
# 20714         20714                 SET FIRE TO THE RAIN HARDSTYLE
# 20715         20715                      OUTSIDE HARDSTYLE SPED UP
# 20716         20716                            ONLY GIRL HARDSTYLE
# 20717         20717                             MISS YOU HARDSTYLE
#
#                                                Album  Energy  \
# 0                                         Demon Days   0.705
# ...

# %%
df7['value'] = 100

# %%
df7
# Out:
#        Unnamed: 0.1  Unnamed: 0       Artist  \
# 0                 0           0     Gorillaz
# 1                 1           1     Gorillaz
# 2                 2           2     Gorillaz
# 3                 3           3     Gorillaz
# 4                 4           4     Gorillaz
# ...             ...         ...          ...
# 20713         20713       20713  SICK LEGEND
# 20714         20714       20714  SICK LEGEND
# 20715         20715       20715  SICK LEGEND
# 20716         20716       20716  SICK LEGEND
# 20717         20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# ...

# %%
import datetime

# %%
df7['Last_Update'] = datetime.datetime.now()

# %%
df7
# Out:
#        Unnamed: 0.1  Unnamed: 0       Artist  \
# 0                 0           0     Gorillaz
# 1                 1           1     Gorillaz
# 2                 2           2     Gorillaz
# 3                 3           3     Gorillaz
# 4                 4           4     Gorillaz
# ...             ...         ...          ...
# 20713         20713       20713  SICK LEGEND
# 20714         20714       20714  SICK LEGEND
# 20715         20715       20715  SICK LEGEND
# 20716         20716       20716  SICK LEGEND
# 20717         20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# ...

# %%
df7
# Out:
#        Unnamed: 0.1  Unnamed: 0       Artist  \
# 0                 0           0     Gorillaz
# 1                 1           1     Gorillaz
# 2                 2           2     Gorillaz
# 3                 3           3     Gorillaz
# 4                 4           4     Gorillaz
# ...             ...         ...          ...
# 20713         20713       20713  SICK LEGEND
# 20714         20714       20714  SICK LEGEND
# 20715         20715       20715  SICK LEGEND
# 20716         20716       20716  SICK LEGEND
# 20717         20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# ...

# %%
df8 = df7[['Artist','Track','Album','Last_Update']]

# %%
df8
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (feat. Tame Impala and Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  SICK LEGEND                           JUST DANCE HARDSTYLE
# 20714  SICK LEGEND                 SET FIRE TO THE RAIN HARDSTYLE
# 20715  SICK LEGEND                      OUTSIDE HARDSTYLE SPED UP
# 20716  SICK LEGEND                            ONLY GIRL HARDSTYLE
# 20717  SICK LEGEND                             MISS YOU HARDSTYLE
#
#                                                Album  \
# 0                                         Demon Days
# 1                                      Plastic Beach
# ...

# %%
df9 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\Ecommerce Customers.csv")

# %%
df9
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df10 = df9[['Email','Avatar','Time on App','Yearly Amount Spent']]

# %%
df10
# Out:
#                              Email            Avatar  Time on App  \
# 0        mstephenson@fernandez.com            Violet    12.655651
# 1                hduke@hotmail.com         DarkGreen    11.109461
# 2                 pallen@yahoo.com            Bisque    11.330278
# 3          riverarebecca@gmail.com       SaddleBrown    13.717514
# 4    mstephens@davidson-herman.com  MediumAquaMarine    12.795189
# ..                             ...               ...          ...
# 495   lewisjessica@craig-evans.com               Tan    13.566160
# 496            katrina56@gmail.com     PaleVioletRed    11.695736
# 497             dale88@hotmail.com          Cornsilk    11.499409
# 498            cwilson@hotmail.com              Teal    12.391423
# 499      hannahwilson@davidson.com       DarkMagenta    12.418808
#
#      Yearly Amount Spent
# 0             587.951054
# 1             392.204933
# 2             487.547505
# 3             581.852344
# 4             599.406092
# ...

# %%
df10['Name'] = df10['Email'].apply(lambda x:x.split('@')[0])
# Out:
# C:\Users\Roshan B\AppData\Local\Temp\ipykernel_11880\3478377088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10['Name'] = df10['Email'].apply(lambda x:x.split('@')[0])

# %%
df10
# Out:
#                              Email            Avatar  Time on App  \
# 0        mstephenson@fernandez.com            Violet    12.655651
# 1                hduke@hotmail.com         DarkGreen    11.109461
# 2                 pallen@yahoo.com            Bisque    11.330278
# 3          riverarebecca@gmail.com       SaddleBrown    13.717514
# 4    mstephens@davidson-herman.com  MediumAquaMarine    12.795189
# ..                             ...               ...          ...
# 495   lewisjessica@craig-evans.com               Tan    13.566160
# 496            katrina56@gmail.com     PaleVioletRed    11.695736
# 497             dale88@hotmail.com          Cornsilk    11.499409
# 498            cwilson@hotmail.com              Teal    12.391423
# 499      hannahwilson@davidson.com       DarkMagenta    12.418808
#
#      Yearly Amount Spent           Name
# 0             587.951054    mstephenson
# 1             392.204933          hduke
# 2             487.547505         pallen
# ...

# %%
df10['Monthly_Amount_Spent'] = df10['Yearly Amount Spent'].apply(lambda x:x/12)
# Out:
# C:\Users\Roshan B\AppData\Local\Temp\ipykernel_11880\3327198440.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10['Monthly_Amount_Spent'] = df10['Yearly Amount Spent'].apply(lambda x:x/12)

# %%
df10
# Out:
#                              Email            Avatar  Time on App  \
# 0        mstephenson@fernandez.com            Violet    12.655651
# 1                hduke@hotmail.com         DarkGreen    11.109461
# 2                 pallen@yahoo.com            Bisque    11.330278
# 3          riverarebecca@gmail.com       SaddleBrown    13.717514
# 4    mstephens@davidson-herman.com  MediumAquaMarine    12.795189
# ..                             ...               ...          ...
# 495   lewisjessica@craig-evans.com               Tan    13.566160
# 496            katrina56@gmail.com     PaleVioletRed    11.695736
# 497             dale88@hotmail.com          Cornsilk    11.499409
# 498            cwilson@hotmail.com              Teal    12.391423
# 499      hannahwilson@davidson.com       DarkMagenta    12.418808
#
#      Yearly Amount Spent           Name  Monthly_Amount_Spent
# 0             587.951054    mstephenson             48.995921
# ...

# %%
df11 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\titanic.csv")

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Encoding by using lambda function

# %%
df11['Encode_New_Gender'] = df11['Sex'].apply(lambda x: 1 if x == 'male' else 0)

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Encoding by using Map function

# %%
df11['Map_New_Gender'] = df11['Sex'].map({'male':1,'female':0})

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Encoding by using Normal function

# %%
def encode(x):
    if x == 'male':
        return 1
    else:
        return 0

# %%
df11['Encode_Normal_Gender'] = df11['Sex'].apply(encode)

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Delete Column from DataFrame

# %%
df11.drop('SibSp',axis=1,inplace = True)     # Sibsp Column delete from df11 DataFrame,inplace means change to original

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Delete Multiple Column from DataFrame

# %%
df11.drop(columns = ["Encode_New_Gender","Map_New_Gender","Encode_Normal_Gender"],axis = 1, inplace = True)

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# fetch Null values

# %%
df11.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  Parch  Ticket   Fare  \
# 0          False     False   False  False  False  False  False   False  False
# 1          False     False   False  False  False  False  False   False  False
# 2          False     False   False  False  False  False  False   False  False
# 3          False     False   False  False  False  False  False   False  False
# 4          False     False   False  False  False  False  False   False  False
# ..           ...       ...     ...    ...    ...    ...    ...     ...    ...
# 886        False     False   False  False  False  False  False   False  False
# 887        False     False   False  False  False  False  False   False  False
# 888        False     False   False  False  False   True  False   False  False
# 889        False     False   False  False  False  False  False   False  False
# 890        False     False   False  False  False  False  False   False  False
#
#      Cabin  Embarked
# ...

# %%
df11.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df11['Cabin'].unique()   # fetch Unique values
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df11
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df11['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
emp_list = {
    'emp_id' : [1,2,3,4,5],
    'emp_name':['Roshan','Ajay','Mohan','Kamal','Rahul'],
    'Dept':['Engg','Design','HR','Purchase','Quality'],
    'DOJ':['17/10/2010','05/06/2015','14/02/2008','18/01/2020','04/09/2000']
}

# %%
df12 = pd.DataFrame(emp_list)

# %%
df12
# Out:
#    emp_id emp_name      Dept         DOJ
# 0       1   Roshan      Engg  17/10/2010
# 1       2     Ajay    Design  05/06/2015
# 2       3    Mohan        HR  14/02/2008
# 3       4    Kamal  Purchase  18/01/2020
# 4       5    Rahul   Quality  04/09/2000

# %%
df12['Date'] = df12['DOJ'].apply(lambda x:x.split('/')[0])

# %%
df12
# Out:
#    emp_id emp_name      Dept         DOJ Date Month
# 0       1   Roshan      Engg  17/10/2010   17    10
# 1       2     Ajay    Design  05/06/2015   05    06
# 2       3    Mohan        HR  14/02/2008   14    02
# 3       4    Kamal  Purchase  18/01/2020   18    01
# 4       5    Rahul   Quality  04/09/2000   04    09

# %%
df12['Month'] = df12['DOJ'].apply(lambda x:x.split('/')[1])

# %%
df12['Year'] = df12['DOJ'].apply(lambda x:x.split('/')[2])

# %%
df12
# Out:
#    emp_id emp_name      Dept         DOJ Date Month  Year
# 0       1   Roshan      Engg  17/10/2010   17    10  2010
# 1       2     Ajay    Design  05/06/2015   05    06  2015
# 2       3    Mohan        HR  14/02/2008   14    02  2008
# 3       4    Kamal  Purchase  18/01/2020   18    01  2020
# 4       5    Rahul   Quality  04/09/2000   04    09  2000

# %%
df12['Salary'] = 45000

# %%
df12
# Out:
#    emp_id emp_name      Dept         DOJ Date Month  Year  Salary
# 0       1   Roshan      Engg  17/10/2010   17    10  2010   45000
# 1       2     Ajay    Design  05/06/2015   05    06  2015   45000
# 2       3    Mohan        HR  14/02/2008   14    02  2008   45000
# 3       4    Kamal  Purchase  18/01/2020   18    01  2020   45000
# 4       5    Rahul   Quality  04/09/2000   04    09  2000   45000

# %%
df12['DOJ'].unique()
# Out:
# array(['17/10/2010', '05/06/2015', '14/02/2008', '18/01/2020',
#        '04/09/2000'], dtype=object)

# %%
df11.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df11.dropna(inplace = True)

# %%
df11.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df11.shape
# Out:
# (891, 12)

# %%
df11.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df13 = df11.fillna(0)

# %%
df11.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df13.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df13.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df13['Age'] = df13['Age'].astype('int64')

# %%
df13.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
