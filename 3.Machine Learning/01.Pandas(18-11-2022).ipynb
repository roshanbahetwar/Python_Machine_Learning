# %%
'hello world'
# Out:
# 'hello world'

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\bengaluru_house_prices.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1 = pd.read_excel(r"C:\Users\Roshan B\Desktop\ML\Dataset\Data_final_pivot_table.xlsx")

# %%
df1
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
py_dict = {
    'name':['Roshan','Ajay','Mohan','Komal'],
    'age':[24,28,29,26],
    'city':['Pune','Nagpur','Mumbai','AurangaBad']
}

# %%
df2 = pd.DataFrame(py_dict)

# %%
df2
# Out:
#      name  age        city
# 0  Roshan   24        Pune
# 1    Ajay   28      Nagpur
# 2   Mohan   29      Mumbai
# 3   Komal   26  AurangaBad

# %%
py_lst = [
    {'id':2104,'name':'Roshan','age':27},
    {'id':2105,'name':'Asha','age':25},
    {'id':2106,'name':'Mohan','age':28},
    {'id':2107,'name':'Ganesh','age':23}
]

# %%
df3 = pd.DataFrame(py_lst)

# %%
df3
# Out:
#      id    name  age
# 0  2104  Roshan   27
# 1  2105    Asha   25
# 2  2106   Mohan   28
# 3  2107  Ganesh   23

# %%
py = (
    {'id':2104,'name':'Roshan','age':27},
    {'id':2105,'name':'Asha','age':25},
    {'id':2106,'name':'Mohan','age':28},
    {'id':2107,'name':'Ganesh','age':23}
    )

# %%
df4 = pd.DataFrame(py)

# %%
df4
# Out:
#      id    name  age
# 0  2104  Roshan   27
# 1  2105    Asha   25
# 2  2106   Mohan   28
# 3  2107  Ganesh   23

# %%
df6 = {
    'id':[1,2,3,4],
    'name':['Roshan','Mohan','Sneha','Ganesh'],
    'age':[29,27,28,26]
}

# %%
import pandas as pd
df7 = pd.DataFrame(df6)

# %%
df7
# Out:
#    id    name  age
# 0   1  Roshan   29
# 1   2   Mohan   27
# 2   3   Sneha   28
# 3   4  Ganesh   26

# %%
import pandas as pd

# %%
lst = {
    'id':[1,2,3,4,5,6],
    'name':['a','b','c','d','e','f'],
    'age':[21,23,25,26,27,21,]
}

# %%
df = pd.DataFrame(lst)
df
# Out:
#    id name  age
# 0   1    a   21
# 1   2    b   23
# 2   3    c   25
# 3   4    d   26
# 4   5    e   27
# 5   6    f   21

# %%
lst1 = [
    {'id':101,'name':'Roshan'},
    {'id':102,'name':'ajay'}
]

# %%
df2 = pd.DataFrame(lst1)
df2
# Out:
#     id    name
# 0  101  Roshan
# 1  102    ajay

# %%
ls = {
    'name':['Mohan','Ganesh'],
    'age':[21,23]
}

# %%
df = pd.DataFrame(ls)
df
# Out:
#      name  age
# 0   Mohan   21
# 1  Ganesh   23

# %%
for i in df:
    print(df[i])
# Out:
# 0     Mohan
# 1    Ganesh
# Name: name, dtype: object
# 0    21
# 1    23
# Name: age, dtype: int64
