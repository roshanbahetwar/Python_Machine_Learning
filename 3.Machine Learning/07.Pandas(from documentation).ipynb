# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Name':['John kennedy','Juliet hons','Peppert Kohn'],
    'Age': [29,24,26],
    'Gender':['Male','Female','Male']
})

# %%
df
# Out:
#            Name  Age  Gender
# 0  John kennedy   29    Male
# 1   Juliet hons   24  Female
# 2  Peppert Kohn   26    Male

# %%
df['Age']
# Out:
# 0    29
# 1    24
# 2    26
# Name: Age, dtype: int64

# %%
ages = pd.Series([21,25,24,23,24,25,20], name = 'Age')

# %%
ages
# Out:
# 0    21
# 1    25
# 2    24
# 3    23
# 4    24
# 5    25
# 6    20
# Name: Age, dtype: int64

# %%
fruits = pd.Series(['apple','mango','banana','grapes'],name = 'Fruits')

# %%
fruits
# Out:
# 0     apple
# 1     mango
# 2    banana
# 3    grapes
# Name: Fruits, dtype: object

# %%
ages.max()
# Out:
# 25

# %%
df['Age'].max()
# Out:
# 29

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   26.333333
# std     2.516611
# min    24.000000
# 25%    25.000000
# 50%    26.000000
# 75%    27.500000
# max    29.000000

# %%
df1 = pd.read_excel('titanic.xlsx')

# %%
df1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df1.head(10)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
# 5           5            6         0       3
# 6           6            7         0       1
# 7           7            8         0       3
# 8           8            9         1       3
# 9           9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df1.tail(3)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 888  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2
# 889                     Behr, Mr. Karl Howell    male  26.0      0      0
# 890                       Dooley, Mr. Patrick    male  32.0      0      0
#
#          Ticket   Fare Cabin Embarked
# 888  W./C. 6607  23.45   NaN        S
# 889      111369  30.00  C148        C
# 890      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# Name      object
# Age        int64
# Gender    object
# dtype: object

# %%
pd.read_excel('titanic.xlsx', sheet_name = 'passengers')
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Gender  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   26.333333
# std     2.516611
# min    24.000000
# 25%    25.000000
# 50%    26.000000
# 75%    27.500000
# max    29.000000

# %%
df
# Out:
#            Name  Age  Gender
# 0  John kennedy   29    Male
# 1   Juliet hons   24  Female
# 2  Peppert Kohn   26    Male

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
df['Age'].shape
# Out:
# (3,)

# %%
df.shape
# Out:
# (3, 3)

# %%
df[['Age','Gender']]
# Out:
#    Age  Gender
# 0   29    Male
# 1   24  Female
# 2   26    Male

# %%
df[['Age','Gender']].shape
# Out:
# (3, 2)

# %%
above_25 = df[df['Age'] >25]  # data greater than 25 age

# %%
above_25.head()
# Out:
#            Name  Age Gender
# 0  John kennedy   29   Male
# 2  Peppert Kohn   26   Male

# %%
df
# Out:
#            Name  Age  Gender
# 0  John kennedy   29    Male
# 1   Juliet hons   24  Female
# 2  Peppert Kohn   26    Male

# %%
df[df['Age']>25]
# Out:
#            Name  Age Gender
# 0  John kennedy   29   Male
# 2  Peppert Kohn   26   Male

# %%
df[df['Name'] == 'Peppert Kohn']
# Out:
#            Name  Age Gender
# 2  Peppert Kohn   26   Male

# %%
df[df['Name']!= 'Peppert Kohn']
# Out:
#            Name  Age  Gender
# 0  John kennedy   29    Male
# 1   Juliet hons   24  Female

# %%
df[df['Gender'] != 'Male']
# Out:
#           Name  Age  Gender
# 1  Juliet hons   24  Female

# %%
df1
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df1[df1['Pclass'].isin([2,3])]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 2             2            3         1       3
# 4             4            5         0       3
# 5             5            6         0       3
# 7             7            8         0       3
# ..          ...          ...       ...     ...
# 884         884          885         0       3
# 885         885          886         0       3
# 886         886          887         0       2
# 888         888          889         0       3
# 890         890          891         0       3
#
#                                          Name     Sex   Age  SibSp  Parch  \
# 0                     Braund, Mr. Owen Harris    male  22.0      1      0
# 2                      Heikkinen, Miss. Laina  female  26.0      0      0
# 4                    Allen, Mr. William Henry    male  35.0      0      0
# 5                            Moran, Mr. James    male   NaN      0      0
# ...

# %%
df1[df1['Sex'].isin(['male'])].shape
# Out:
# (577, 13)

# %%
df1[(df1['Age'] == 22) | (df1['Age'] == 25)]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 60           60           61         0       3
# 75           75           76         0       3
# 80           80           81         0       3
# 112         112          113         0       3
# 134         134          135         0       2
# 141         141          142         1       3
# 151         151          152         1       1
# 212         212          213         0       3
# 225         225          226         0       3
# 243         243          244         0       3
# 246         246          247         0       3
# 267         267          268         1       3
# 271         271          272         1       3
# 287         287          288         0       3
# 289         289          290         1       3
# 320         320          321         0       3
# 323         323          324         1       2
# 343         343          344         0       2
# ...

# %%
df1.groupby('Age').get_group(25)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 75           75           76         0       3
# 134         134          135         0       2
# 246         246          247         0       3
# 267         267          268         1       3
# 271         271          272         1       3
# 343         343          344         0       2
# 353         353          354         0       3
# 370         370          371         1       1
# 442         442          443         0       3
# 484         484          485         1       1
# 498         498          499         0       1
# 580         580          581         1       2
# 666         666          667         0       2
# 685         685          686         0       2
# 693         693          694         0       3
# 703         703          704         0       3
# 728         728          729         0       2
# 729         729          730         0       3
# 784         784          785         0       3
# ...

# %%
df1[df1['Age'].notna()]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 885         885          886         0       3
# 886         886          887         0       2
# 887         887          888         1       1
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df1.loc[df1['Age']<20, ['Name','Age']]
# Out:
#                                      Name   Age
# 7          Palsson, Master. Gosta Leonard   2.0
# 9     Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10        Sandstrom, Miss. Marguerite Rut   4.0
# 14   Vestrom, Miss. Hulda Amanda Adolfina  14.0
# 16                   Rice, Master. Eugene   2.0
# ..                                    ...   ...
# 855            Aks, Mrs. Sam (Leah Rosen)  18.0
# 869       Johnson, Master. Harold Theodor   4.0
# 875      Najib, Miss. Adele Kiamie "Jane"  15.0
# 877                  Petroff, Mr. Nedelio  19.0
# 887          Graham, Miss. Margaret Edith  19.0
#
# [164 rows x 2 columns]

# %%
df1.loc[1:4,'Name':'Age']
# Out:
#                                                 Name     Sex   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df1.loc[[1,5],['Name','Age']]
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 5                                   Moran, Mr. James   NaN

# %%
df1.iloc[[1,2,3],[1,2,6]]
# Out:
#    PassengerId  Survived   Age
# 1            2         1  38.0
# 2            3         1  26.0
# 3            4         1  35.0

# %%
df1.iloc[1:10,1:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df1.iloc[0:3,3] = 'anonymous'

# %%
df1.head()
# Out:
#    Unnamed: 0  PassengerId  Survived     Pclass  \
# 0           0            1         0  anonymous
# 1           1            2         1  anonymous
# 2           2            3         1  anonymous
# 3           3            4         1          1
# 4           4            5         0          3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
air_qaulity = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\air_quality_no2.csv", index_col=0,parse_dates=True)

air_qaulity.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_qaulity.plot()

plt.show()

# %%
air_qaulity['station_paris'].plot()
plt.show()

# %%
air_qaulity['station_antwerp'].plot()
plt.show()

# %%
air_qaulity['station_london'].plot()
plt.show()

# %%
air_qaulity.plot.scatter(x= 'station_london',y= 'station_paris', alpha = 0.5)
plt.show()

# %%
[method_name
for method_name in dir(air_qaulity.plot)
if not method_name.startswith('_')]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
dir(air_qaulity.plot)
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_all_kinds',
#  '_common_kinds',
#  '_constructor',
#  '_dataframe_kinds',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_call_args',
#  '_hidden_attrs',
#  '_kind_aliases',
#  '_parent',
#  '_reset_cache',
#  '_series_kinds',
#  'area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_qaulity.plot.area()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
axs = air_qaulity.plot.area(figsize = (12,4),subplots = True)
plt.show()

# %%
air_qaulity.plot.box()
# Out:
# <AxesSubplot:>

# %%
fig,axs = plt.subplots(figsize = (12,4))       # Create an empty Matplotlib Figure and Axes

air_qaulity.plot.area(ax = axs)                # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("NO$_2$ Concentration")         # Do any Matplotlib customization you like
fig.savefig('no2_concentration.png')           # Save the Figure/Axes using the existing Matplotlib method.
plt.show()                                     # Display the plot

# %%
# How to create new columns, derived from existing columns

air_qaulity['london_mg_per_cubic'] = air_qaulity['station_london']*1.882
air_qaulity.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
# to check the ratio of the values in Paris versus Antwerp and save the result in a new column.

air_qaulity['ratio_paris_antwerp'] = (air_qaulity['station_paris']/air_qaulity['station_antwerp'])

air_qaulity.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
# rename the data columns to the corresponding station identifiers

air_qaulity_renamed = air_qaulity.rename(
columns = {
    'station_antwerp' : 'BETR801',
    'station_paris' : 'FR04014',
    'station_london' : 'London_westminster'
})

# %%
air_qaulity_renamed
# Out:
#                      BETR801  FR04014  London_westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# ...

# %%
air_qaulity_renamed = air_qaulity_renamed.rename(columns=str.lower)

# %%
air_qaulity_renamed
# Out:
#                      betr801  fr04014  london_westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                      ...      ...                 ...
# 2019-06-20 22:00:00      NaN     21.4                 NaN
# 2019-06-20 23:00:00      NaN     24.9                 NaN
# 2019-06-21 00:00:00      NaN     26.5                 NaN
# 2019-06-21 01:00:00      NaN     21.8                 NaN
# 2019-06-21 02:00:00      NaN     20.0                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# ...

# %%
import pandas as pd

# %%
df4 = pd.DataFrame({
    'id':[11,12,13,14,15,16],
    'name':['Roshan','Ajay','Mohan','Ganesh','Komal','Kishore'],
    'age':[21,22,23,24,26,25],
    'Salary':[21111,25000,23500,24655,35600,65200]
})

# %%
df4
# Out:
#    id     name  age  Salary
# 0  11   Roshan   21   21111
# 1  12     Ajay   22   25000
# 2  13    Mohan   23   23500
# 3  14   Ganesh   24   24655
# 4  15    Komal   26   35600
# 5  16  Kishore   25   65200

# %%
import matplotlib.pyplot as plt

# %%
df4.plot()
plt.show()

# %%
df4['Salary'].plot()
plt.show()

# %%
df4.plot.scatter(x = 'age',y = 'Salary',alpha = 0.9)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Salary'>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df4[['Salary','age']].plot()
plt.show()

# %%
df4.plot.area(figsize = (12,3),subplots = True)
df4.set_ylabel('age')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 2>()
#       1 df4.plot.area(figsize = (12,3),subplots = True)
# ----> 2 df4.set_ylabel('age')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_ylabel'

# %%
fig,axs = plt.subplots(figsize = (12,4))       # Create an empty Matplotlib Figure and Axes

air_qaulity.plot.area(ax = axs)                # Use pandas to put the area plot on the prepared Figure/Axes
axs.set_ylabel("NO$_2$ Concentration")         # Do any Matplotlib customization you like
fig.savefig('no2_concentration.png')           # Save the Figure/Axes using the existing Matplotlib method.
plt.show()                                     # Display the plot
