# %%
from matplotlib import pyplot as plt

# %%
age = [24,26,30,65,45,25,65]
salary = [25000,65000,95000,45000,35000,78500,85600]

# %%
plt.scatter(age,salary,marker='*')

# %%
plt.plot(age,salary,marker = '*',markersize = 10)

# %%
plt.bar(age,salary)
# Out:
# <BarContainer object of 7 artists>

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv")

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
plt.scatter(df['star_rating'],df['genre'])

# %%
plt.plot(df['star_rating'],df['genre'],marker = '*')

# %%
plt.bar(df['star_rating'],df['genre'])
# Out:
# <BarContainer object of 979 artists>

# %%
plt.plot(df['star_rating'],df['genre'],marker = '*',markersize = 8)
plt.title('Test')
plt.xlabel('Star_rating')
plt.ylabel('Genre')
plt.legend('G')

# %%
df.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
BJP = [150,250,100,65,48,250,241,350]
CNG = [350,200,65,45,65,145,189,230]

# %%
plt.scatter(BJP,CNG)

# %%
plt.plot(BJP,CNG, marker = '*',markersize = 8)
plt.title('Election')
plt.xlabel('BJP')
plt.ylabel('CNG')
plt.legend('V')

# %%
plt.bar(BJP,CNG)
# Out:
# <BarContainer object of 8 artists>

# %%
X = ['Python34','Python35','Python36','Python37','Python38']
girls = [65,55,48,95,65]
boys = [77,85,56,25,89]

# %%
import numpy as np

# %%
x_axis = np.arange(len(X))

# %%
x_axis
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.bar(x_axis-0.2,boys,0.4,label = 'Boys')
plt.bar(x_axis+0.2,girls,0.4,label = 'Girls')
plt.xticks(x_axis,X)
plt.legend()

# %%
Village = ['Chikhali','Kkurkheda','Gewardha','Wadsa']
male = [1500,900,1200,1700]
female = [2000,1500,1900,1600]

# %%
import numpy as np

# %%
x_axis = np.arange(len(Village))

# %%
x_axis
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(x_axis-0.2,male,0.4,label = 'Male')
plt.bar(x_axis+0.2,female,0.4,label = 'Female')
plt.xticks(x_axis,Village)
plt.legend()

# %%
plt.plot(x_axis-0.2,male,0.4,label = 'Male')
plt.plot(x_axis+0.2,female,0.4,label = 'Female')
plt.xticks(x_axis,Village)
plt.legend()

# %%
Date = [1,2,3,4,5,6,7,8]
Temp = [25.1,39,41.2,44,38.7,45,36,39]

# %%
plt.plot(Date,Temp,marker = '*',markersize=8)
plt.title('Weather')
plt.xlabel("Date")
plt.ylabel("Temprature")
plt.legend('T')

# %%
plt.bar(Date,Temp)
# Out:
# <BarContainer object of 8 artists>
