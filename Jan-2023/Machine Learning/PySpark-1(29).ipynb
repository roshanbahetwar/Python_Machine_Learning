# %%
import pyspark as ps

# %%
spark = ps.sql.SparkSession.builder.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-AT3H5HSA:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
type(spark)
# Out:
# pyspark.sql.session.SparkSession

# %%
df = spark.read.csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv",header = True, inferSchema = True)

# %%
# by default its output datatype is in string, so getting original datatype need to write inferSchema = True

# %%
df.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.printSchema()        # for data type check
# Out:
# root
#  |-- star_rating: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- content_rating: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- actors_list: string (nullable = true)

# %%
df.show(150)       # showing 150 nos records
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.columns
# Out:
# ['star_rating', 'title', 'content_rating', 'genre', 'duration', 'actors_list']

# %%
df.count()     # fetch total no of rows from dataset
# Out:
# 979

# %%
df.describe()
# Out:
# DataFrame[summary: string, star_rating: string, title: string, content_rating: string, genre: string, duration: string, actors_list: string]

# %%
df.describe().show()
# Out:
# +-------+-------------------+--------------------+--------------+-------+------------------+--------------------+
# |summary|        star_rating|               title|content_rating|  genre|          duration|         actors_list|
# +-------+-------------------+--------------------+--------------+-------+------------------+--------------------+
# |  count|                979|                 979|           976|    979|               979|                 979|
# |   mean| 7.8897854954034985|               796.0|          null|   null|120.97957099080695|                null|
# | stddev|0.33606932614795176|   1090.190808987124|          null|   null|26.218009846412077|                null|
# |    min|                7.4|(500) Days of Summer|      APPROVED| Action|                64|"[u""Brian O'Hall...|
# |    max|                9.3|               [Rec]|             X|Western|               242|[u'Zooey Deschane...|
# ...

# %%
df.first()     # fetch first records in tuple
# Out:
# Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']")

# %%
df.head(5)     # show 5 nos record from top
# Out:
# [Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"),
#  Row(star_rating=9.2, title='The Godfather', content_rating='R', genre='Crime', duration=175, actors_list="[u'Marlon Brando', u'Al Pacino', u'James Caan']"),
#  Row(star_rating=9.1, title='The Godfather: Part II', content_rating='R', genre='Crime', duration=200, actors_list="[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"),
#  Row(star_rating=9.0, title='The Dark Knight', content_rating='PG-13', genre='Action', duration=152, actors_list="[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']"),
#  Row(star_rating=8.9, title='Pulp Fiction', content_rating='R', genre='Crime', duration=154, actors_list="[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']")]

# %%
df.tail(5)       # show 5 nos record from bottom
# Out:
# [Row(star_rating=7.4, title='Tootsie', content_rating='PG', genre='Comedy', duration=116, actors_list="[u'Dustin Hoffman', u'Jessica Lange', u'Teri Garr']"),
#  Row(star_rating=7.4, title='Back to the Future Part III', content_rating='PG', genre='Adventure', duration=118, actors_list="[u'Michael J. Fox', u'Christopher Lloyd', u'Mary Steenburgen']"),
#  Row(star_rating=7.4, title='Master and Commander: The Far Side of the World', content_rating='PG-13', genre='Action', duration=138, actors_list="[u'Russell Crowe', u'Paul Bettany', u'Billy Boyd']"),
#  Row(star_rating=7.4, title='Poltergeist', content_rating='PG', genre='Horror', duration=114, actors_list='"[u\'JoBeth Williams\', u""Heather O\'Rourke""'),
#  Row(star_rating=7.4, title='Wall Street', content_rating='R', genre='Crime', duration=126, actors_list="[u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']")]

# %%
df.collect()
# Out:
# [Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"),
#  Row(star_rating=9.2, title='The Godfather', content_rating='R', genre='Crime', duration=175, actors_list="[u'Marlon Brando', u'Al Pacino', u'James Caan']"),
#  Row(star_rating=9.1, title='The Godfather: Part II', content_rating='R', genre='Crime', duration=200, actors_list="[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"),
#  Row(star_rating=9.0, title='The Dark Knight', content_rating='PG-13', genre='Action', duration=152, actors_list="[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']"),
#  Row(star_rating=8.9, title='Pulp Fiction', content_rating='R', genre='Crime', duration=154, actors_list="[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']"),
# ...

# %%
df.collect()[5]   # collects method collect data from all cluster and show
# Out:
# Row(star_rating=8.9, title='12 Angry Men', content_rating='NOT RATED', genre='Drama', duration=96, actors_list="[u'Henry Fonda', u'Lee J. Cobb', u'Martin Balsam']")

# %%
df.select('title','duration').show()   # select use :- fetch particular column or columns
# Out:
# +--------------------+--------+
# |               title|duration|
# +--------------------+--------+
# |The Shawshank Red...|     142|
# |       The Godfather|     175|
# |The Godfather: Pa...|     200|
# |     The Dark Knight|     152|
# |        Pulp Fiction|     154|
# |        12 Angry Men|      96|
# |The Good, the Bad...|     161|
# |The Lord of the R...|     201|
# |    Schindler's List|     195|
# |          Fight Club|     139|
# |The Lord of the R...|     178|
# |           Inception|     148|
# |Star Wars: Episod...|     124|
# |        Forrest Gump|     142|
# |The Lord of the R...|     179|
# |        Interstellar|     169|
# |One Flew Over the...|     133|
# |       Seven Samurai|     207|
# |          Goodfellas|     146|
# |           Star Wars|     121|
# +--------------------+--------+
# only showing top 20 rows

# %%
# EDA---> pandas    (# pandas and pyspark nearly same for EDA both can be used, due to huge amount of dataset pyspark to be used)
# EDA---> pyspark
# storage ---> csv-->pyspark--->csv format  (# pyspark is a computing engine)

# %%
df.select('star_rating','title','duration').filter('duration<150').show()  # fetch perticular column and filter out in duration
# Out:
# +-----------+--------------------+--------+
# |star_rating|               title|duration|
# +-----------+--------------------+--------+
# |        9.3|The Shawshank Red...|     142|
# |        8.9|        12 Angry Men|      96|
# |        8.9|          Fight Club|     139|
# |        8.8|           Inception|     148|
# |        8.8|Star Wars: Episod...|     124|
# |        8.8|        Forrest Gump|     142|
# |        8.7|One Flew Over the...|     133|
# |        8.7|          Goodfellas|     146|
# |        8.7|           Star Wars|     121|
# |        8.7|          The Matrix|     136|
# |        8.7|         City of God|     130|
# |        8.7|It's a Wonderful ...|     130|
# |        8.7|  The Usual Suspects|     106|
# |        8.7|               Se7en|     127|
# |        8.6|   Life Is Beautiful|     116|
# |        8.6|The Silence of th...|     118|
# |        8.6|Leon: The Profess...|     110|
# |        8.6|         City Lights|      87|
# ...

# %%
df.select('star_rating','title').filter('star_rating<8.7').select('title').show(50)
# Out:
# +--------------------+
# |               title|
# +--------------------+
# |   Life Is Beautiful|
# |Once Upon a Time ...|
# |The Silence of th...|
# |Leon: The Profess...|
# |         City Lights|
# |       Spirited Away|
# |    The Intouchables|
# |          Casablanca|
# |            Whiplash|
# |  American History X|
# |        Modern Times|
# | Saving Private Ryan|
# |Raiders of the Lo...|
# |         Rear Window|
# |              Psycho|
# |      The Green Mile|
# |        Sunset Blvd.|
# |         The Pianist|
# |The Dark Knight R...|
# |           Gladiator|
# |Terminator 2: Jud...|
# |             Memento|
# |    Taare Zameen Par|
# |Dr. Strangelove o...|
# |        The Departed|
# |     Cinema Paradiso|
# |      Apocalypse Now|
# |  The Great Dictator|
# |        The Prestige|
# |  Back to the Future|
# |       The Lion King|
# | The Lives of Others|
# |               Alien|
# |      Paths of Glory|
# |    Django Unchained|
# |            3 Idiots|
# |Grave of the Fire...|
# ...

# %%
df.select('genre').distinct().count()    # for check unique and count
# Out:
# 16

# %%
df.select('genre').distinct().show()     # for fetch unique records
# Out:
# +---------+
# |    genre|
# +---------+
# |    Crime|
# | Thriller|
# |Adventure|
# |    Drama|
# |   Family|
# |  Fantasy|
# |  History|
# |  Mystery|
# |Animation|
# |Film-Noir|
# |   Horror|
# |  Western|
# |Biography|
# |   Comedy|
# |   Action|
# |   Sci-Fi|
# +---------+

# %%
df.describe('genre').show()
# Out:
# +-------+-------+
# |summary|  genre|
# +-------+-------+
# |  count|    979|
# |   mean|   null|
# | stddev|   null|
# |    min| Action|
# |    max|Western|
# +-------+-------+

# %%
df.groupby('genre').count().show()
# Out:
# +---------+-----+
# |    genre|count|
# +---------+-----+
# |    Crime|  124|
# | Thriller|    5|
# |Adventure|   75|
# |    Drama|  278|
# |   Family|    2|
# |  Fantasy|    1|
# |  History|    1|
# |  Mystery|   16|
# |Animation|   62|
# |Film-Noir|    3|
# |   Horror|   29|
# |  Western|    9|
# |Biography|   77|
# |   Comedy|  156|
# |   Action|  136|
# |   Sci-Fi|    5|
# +---------+-----+

# %%
df.groupby('genre').count().toPandas()      # convert into pandas dataframe
# Out:
#         genre  count
# 0       Crime    124
# 1    Thriller      5
# 2   Adventure     75
# 3       Drama    278
# 4      Family      2
# 5     Fantasy      1
# 6     History      1
# 7     Mystery     16
# 8   Animation     62
# 9   Film-Noir      3
# 10     Horror     29
# 11    Western      9
# 12  Biography     77
# 13     Comedy    156
# 14     Action    136
# 15     Sci-Fi      5

# %%
df.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.groupby('content_rating').count().show()
# Out:
# +--------------+-----+
# |content_rating|count|
# +--------------+-----+
# |        PASSED|    7|
# |      APPROVED|   47|
# |          null|    3|
# |            PG|  123|
# |         TV-MA|    1|
# |         NC-17|    7|
# |             X|    4|
# |             R|  460|
# |     NOT RATED|   65|
# |             G|   32|
# |            GP|    3|
# |       UNRATED|   38|
# |         PG-13|  189|
# +--------------+-----+

# %%
df.groupby('content_rating').count().toPandas()
# Out:
#    content_rating  count
# 0          PASSED      7
# 1        APPROVED     47
# 2            None      3
# 3              PG    123
# 4           TV-MA      1
# 5           NC-17      7
# 6               X      4
# 7               R    460
# 8       NOT RATED     65
# 9               G     32
# 10             GP      3
# 11        UNRATED     38
# 12          PG-13    189

# %%
df.toPandas()    # Convert Pyspark dataframe into pandas
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.count()
# Out:
# 979

# %%
df.dropna().show()       # duplicate values drop or same row drop
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.dropna().count()      # duplicate values drop or same row drop
# Out:
# 976

# %%
df.dropna('any').show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.dropna('all').show()    # drop null values
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.agg({'star_rating':'max'}).show()    # fetch max value from star_rating
# Out:
# +----------------+
# |max(star_rating)|
# +----------------+
# |             9.3|
# +----------------+

# %%
df.agg({'duration':'min','star_rating':'max'}).show()   # minimum value from duration and max value from star_rating
# Out:
# +-------------+----------------+
# |min(duration)|max(star_rating)|
# +-------------+----------------+
# |           64|             9.3|
# +-------------+----------------+

# %%
df.agg({'star_rating':'max','duration':'max','genre':'max'}).show()  # fetch max value from star_rating,duartion,and genre
# Out:
# +-------------+----------------+----------+
# |max(duration)|max(star_rating)|max(genre)|
# +-------------+----------------+----------+
# |          242|             9.3|   Western|
# +-------------+----------------+----------+

# %%
df.agg({'duration':'sum','star_rating':'sum'}).show()    # for sum of all values from duration column
# Out:
# +-------------+-----------------+
# |sum(duration)| sum(star_rating)|
# +-------------+-----------------+
# |       118439|7724.100000000025|
# +-------------+-----------------+

# %%
df.agg({'duration':'avg'}).show()            # fetch avg of duration column
# Out:
# +------------------+
# |     avg(duration)|
# +------------------+
# |120.97957099080695|
# +------------------+

# %%
df.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
import pandas as pd         # import pandas

# %%
df1 = pd.DataFrame({'id':[1,2,3,4,5],
                   'name':['Roshan','Asha','Komal','Sneha','Mohan']})     # create dataframe in pandas

# %%
df1       # show dataframe
# Out:
#    id    name
# 0   1  Roshan
# 1   2    Asha
# 2   3   Komal
# 3   4   Sneha
# 4   5   Mohan

# %%
df2 = pd.DataFrame({'id':[2,3,5,1,6,4,7],
                   'Dept':['A','B','C','D','E','F','G'],
                   'salary':[100,250,350,140,254,365,652]})               # create dataframe in pandas

# %%
df2     # show dataframe
# Out:
#    id Dept  salary
# 0   2    A     100
# 1   3    B     250
# 2   5    C     350
# 3   1    D     140
# 4   6    E     254
# 5   4    F     365
# 6   7    G     652

# %%
df1.to_csv('p_test')         # convert pandas dataframe df1 into csv file as filename 'p_test'

# %%
df2.to_csv('q_test')         # convert pandas dataframe df2 into csv file as filename 'q_test'

# %%
df3 = spark.read.csv('p_test',header = True,inferSchema= True)   # read csv file 'p_test' in pyspark  and store in df3

# %%
df3.show()   # show df3
# Out:
# +---+---+------+
# |_c0| id|  name|
# +---+---+------+
# |  0|  1|Roshan|
# |  1|  2|  Asha|
# |  2|  3| Komal|
# |  3|  4| Sneha|
# |  4|  5| Mohan|
# +---+---+------+

# %%
df4 = spark.read.csv('q_test', header = True, inferSchema = True)    # read csv file 'q_test' in pyspark and store in df4

# %%
df4.show()   # show df4
# Out:
# +---+---+----+------+
# |_c0| id|Dept|salary|
# +---+---+----+------+
# |  0|  2|   A|   100|
# |  1|  3|   B|   250|
# |  2|  5|   C|   350|
# |  3|  1|   D|   140|
# |  4|  6|   E|   254|
# |  5|  4|   F|   365|
# |  6|  7|   G|   652|
# +---+---+----+------+

# %%
df3.join(df4,df3.id == df4.id).show()     # join df3 and df4, with same column 'id'
# Out:
# +---+---+------+---+---+----+------+
# |_c0| id|  name|_c0| id|Dept|salary|
# +---+---+------+---+---+----+------+
# |  1|  2|  Asha|  0|  2|   A|   100|
# |  2|  3| Komal|  1|  3|   B|   250|
# |  4|  5| Mohan|  2|  5|   C|   350|
# |  0|  1|Roshan|  3|  1|   D|   140|
# |  3|  4| Sneha|  5|  4|   F|   365|
# +---+---+------+---+---+----+------+

# %%
df.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.orderBy('star_rating').show()          # by default in ascending order
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        7.4|     Man on the Moon|             R|Biography|     118|[u'Jim Carrey', u...|
# |        7.4|               Bound|             R|    Crime|     108|[u'Jennifer Tilly...|
# |        7.4|        Mean Streets|             R|    Crime|     112|[u'Robert De Niro...|
# |        7.4|Harry Potter and ...|         PG-13|Adventure|     138|[u'Daniel Radclif...|
# |        7.4|         Beetlejuice|            PG|   Comedy|      92|[u'Alec Baldwin',...|
# |        7.4|Crazy, Stupid, Love.|         PG-13|   Comedy|     118|[u'Steve Carell',...|
# |        7.4|           Excalibur|             R|Adventure|     140|[u'Nigel Terry', ...|
# ...

# %%
df.sort(df.star_rating.desc()).show()     # descending order
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|          Fight Club|             R|    Drama|     139|[u'Brad Pitt', u'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# ...

# %%
#  New Column add with calculation

# %%
df5 = df.withColumn('new_duration',df.duration/50)

# %%
df5.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|new_duration|
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|        2.84|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|         3.5|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|         4.0|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|        3.04|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|        3.08|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|        1.92|
# ...

# %%
df6 = df5.drop('new_duration')     # drop new column

# %%
df6.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...
