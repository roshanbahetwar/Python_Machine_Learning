# %%
# ******Read File Through Pyspark*******

# %%
# !pip install pyspark     'install pyspark'

# %%
# pip install sparksql-magic

# %%
import pyspark as ps

# %%
spark = ps.sql.SparkSession.builder.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-AT3H5HSA:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
type(spark)
# Out:
# pyspark.sql.session.SparkSession

# %%
df = spark.read.csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv",header=True, inferSchema=True)  

# when it will be read the type of all data will be in string, so convert datatype according to column header write--> inferSchema = True

# %%
df
# Out:
# DataFrame[star_rating: double, title: string, content_rating: string, genre: string, duration: int, actors_list: string]

# %%
df.show()   # for show table data
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
# to check datatype

df.printSchema()
# Out:
# root
#  |-- star_rating: double (nullable = true)
#  |-- title: string (nullable = true)
#  |-- content_rating: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- actors_list: string (nullable = true)

# %%
df.columns   # fetch columns
# Out:
# ['star_rating', 'title', 'content_rating', 'genre', 'duration', 'actors_list']

# %%
df.describe()   # show summary of data
# Out:
# DataFrame[summary: string, star_rating: string, title: string, content_rating: string, genre: string, duration: string, actors_list: string]

# %%
df.count()    # no. of rows
# Out:
# 979

# %%
df.first()   # fetch first row
# Out:
# Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']")

# %%
df.collect()[2]      # fetch record of index no.--> 2
# Out:
# Row(star_rating=9.1, title='The Godfather: Part II', content_rating='R', genre='Crime', duration=200, actors_list="[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']")

# %%
df.dtypes   # types of column
# Out:
# [('star_rating', 'double'),
#  ('title', 'string'),
#  ('content_rating', 'string'),
#  ('genre', 'string'),
#  ('duration', 'int'),
#  ('actors_list', 'string')]

# %%
df.show(5)
# Out:
# +-----------+--------------------+--------------+------+--------+--------------------+
# |star_rating|               title|content_rating| genre|duration|         actors_list|
# +-----------+--------------------+--------------+------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R| Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R| Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R| Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R| Crime|     154|[u'John Travolta'...|
# +-----------+--------------------+--------------+------+--------+--------------------+
# only showing top 5 rows

# %%
df.head(5)
# Out:
# [Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"),
#  Row(star_rating=9.2, title='The Godfather', content_rating='R', genre='Crime', duration=175, actors_list="[u'Marlon Brando', u'Al Pacino', u'James Caan']"),
#  Row(star_rating=9.1, title='The Godfather: Part II', content_rating='R', genre='Crime', duration=200, actors_list="[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"),
#  Row(star_rating=9.0, title='The Dark Knight', content_rating='PG-13', genre='Action', duration=152, actors_list="[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']"),
#  Row(star_rating=8.9, title='Pulp Fiction', content_rating='R', genre='Crime', duration=154, actors_list="[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']")]

# %%
df.tail(5)
# Out:
# [Row(star_rating=7.4, title='Tootsie', content_rating='PG', genre='Comedy', duration=116, actors_list="[u'Dustin Hoffman', u'Jessica Lange', u'Teri Garr']"),
#  Row(star_rating=7.4, title='Back to the Future Part III', content_rating='PG', genre='Adventure', duration=118, actors_list="[u'Michael J. Fox', u'Christopher Lloyd', u'Mary Steenburgen']"),
#  Row(star_rating=7.4, title='Master and Commander: The Far Side of the World', content_rating='PG-13', genre='Action', duration=138, actors_list="[u'Russell Crowe', u'Paul Bettany', u'Billy Boyd']"),
#  Row(star_rating=7.4, title='Poltergeist', content_rating='PG', genre='Horror', duration=114, actors_list='"[u\'JoBeth Williams\', u""Heather O\'Rourke""'),
#  Row(star_rating=7.4, title='Wall Street', content_rating='R', genre='Crime', duration=126, actors_list="[u'Charlie Sheen', u'Michael Douglas', u'Tamara Tunie']")]

# %%
# filter on dataframe, to fetch perticular columns

df.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.select('genre','title','duration').show()
# Out:
# +---------+--------------------+--------+
# |    genre|               title|duration|
# +---------+--------------------+--------+
# |    Crime|The Shawshank Red...|     142|
# |    Crime|       The Godfather|     175|
# |    Crime|The Godfather: Pa...|     200|
# |   Action|     The Dark Knight|     152|
# |    Crime|        Pulp Fiction|     154|
# |    Drama|        12 Angry Men|      96|
# |  Western|The Good, the Bad...|     161|
# |Adventure|The Lord of the R...|     201|
# |Biography|    Schindler's List|     195|
# |    Drama|          Fight Club|     139|
# |Adventure|The Lord of the R...|     178|
# |   Action|           Inception|     148|
# |   Action|Star Wars: Episod...|     124|
# |    Drama|        Forrest Gump|     142|
# |Adventure|The Lord of the R...|     179|
# |Adventure|        Interstellar|     169|
# |    Drama|One Flew Over the...|     133|
# |    Drama|       Seven Samurai|     207|
# |Biography|          Goodfellas|     146|
# ...

# %%
df.select('genre','duration').filter('duration>195').show()
# Out:
# +---------+--------+
# |    genre|duration|
# +---------+--------+
# |    Crime|     200|
# |Adventure|     201|
# |    Drama|     207|
# |    Crime|     229|
# |Adventure|     216|
# |Adventure|     224|
# |    Drama|     238|
# |Adventure|     212|
# |    Drama|     197|
# |   Action|     197|
# |Adventure|     220|
# |    Drama|     242|
# |Biography|     202|
# |   Action|     205|
# +---------+--------+

# %%
df.select('genre').distinct().show()   # unique
# Out:
# +---------+
# |    genre|
# +---------+
# |    Crime|
# | Thriller|
# |Adventure|
# |    Drama|
# |   Family|
# |  Fantasy|
# |  History|
# |  Mystery|
# |Animation|
# |Film-Noir|
# |   Horror|
# |  Western|
# |Biography|
# |   Comedy|
# |   Action|
# |   Sci-Fi|
# +---------+

# %%
df.select('genre','title','duration','star_rating').filter('star_rating>8').show()
# Out:
# +---------+--------------------+--------+-----------+
# |    genre|               title|duration|star_rating|
# +---------+--------------------+--------+-----------+
# |    Crime|The Shawshank Red...|     142|        9.3|
# |    Crime|       The Godfather|     175|        9.2|
# |    Crime|The Godfather: Pa...|     200|        9.1|
# |   Action|     The Dark Knight|     152|        9.0|
# |    Crime|        Pulp Fiction|     154|        8.9|
# |    Drama|        12 Angry Men|      96|        8.9|
# |  Western|The Good, the Bad...|     161|        8.9|
# |Adventure|The Lord of the R...|     201|        8.9|
# |Biography|    Schindler's List|     195|        8.9|
# |    Drama|          Fight Club|     139|        8.9|
# |Adventure|The Lord of the R...|     178|        8.8|
# |   Action|           Inception|     148|        8.8|
# |   Action|Star Wars: Episod...|     124|        8.8|
# |    Drama|        Forrest Gump|     142|        8.8|
# ...

# %%
df.select('genre').count()
# Out:
# 979

# %%
df.groupby('genre').count().show()
# Out:
# +---------+-----+
# |    genre|count|
# +---------+-----+
# |    Crime|  124|
# | Thriller|    5|
# |Adventure|   75|
# |    Drama|  278|
# |   Family|    2|
# |  Fantasy|    1|
# |  History|    1|
# |  Mystery|   16|
# |Animation|   62|
# |Film-Noir|    3|
# |   Horror|   29|
# |  Western|    9|
# |Biography|   77|
# |   Comedy|  156|
# |   Action|  136|
# |   Sci-Fi|    5|
# +---------+-----+

# %%
df.dropna().show()    # duplicate values drop or same row drop
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.dropna().count()
# Out:
# 976

# %%
df.count()
# Out:
# 979

# %%
a = df.toPandas()

# %%
a.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
df.toPandas()
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
a.to_csv('test_new.csv')

# %%
import pandas as pd
pd.read_csv('test_new.csv')
# Out:
#      Unnamed: 0  star_rating                                            title  \
# 0             0          9.3                         The Shawshank Redemption
# 1             1          9.2                                    The Godfather
# 2             2          9.1                           The Godfather: Part II
# 3             3          9.0                                  The Dark Knight
# 4             4          8.9                                     Pulp Fiction
# ..          ...          ...                                              ...
# 974         974          7.4                                          Tootsie
# 975         975          7.4                      Back to the Future Part III
# 976         976          7.4  Master and Commander: The Far Side of the World
# 977         977          7.4                                      Poltergeist
# 978         978          7.4                                      Wall Street
#
# ...

# %%
df.dropna('any').show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.dropna('all').show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df.select('star_rating').show()
# Out:
# +-----------+
# |star_rating|
# +-----------+
# |        9.3|
# |        9.2|
# |        9.1|
# |        9.0|
# |        8.9|
# |        8.9|
# |        8.9|
# |        8.9|
# |        8.9|
# |        8.9|
# |        8.8|
# |        8.8|
# |        8.8|
# |        8.8|
# |        8.8|
# |        8.7|
# |        8.7|
# |        8.7|
# |        8.7|
# |        8.7|
# +-----------+
# only showing top 20 rows
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 df.select('star_rating').show().max()
#
# AttributeError: 'NoneType' object has no attribute 'max'

# %%
a['star_rating'].max()    # in pandas max value fetch
# Out:
# 9.3

# %%
df.agg({'star_rating':'max'}).show()   # in pyspark max value fetch by using agg
# Out:
# +----------------+
# |max(star_rating)|
# +----------------+
# |             9.3|
# +----------------+

# %%
df.agg({'star_rating':'min'}).show()      # in pyspark min value fetch by using agg
# Out:
# +----------------+
# |min(star_rating)|
# +----------------+
# |             7.4|
# +----------------+

# %%
df.agg({'duration':'sum'}).show()      # in pyspark sum value fetch by using agg
# Out:
# +-------------+
# |sum(duration)|
# +-------------+
# |       118439|
# +-------------+

# %%
df.agg({'duration':'avg'}).show()     # in pyspark avg value fetch by using agg
# Out:
# +------------------+
# |     avg(duration)|
# +------------------+
# |120.97957099080695|
# +------------------+

# %%
df.agg({'duration':'max','star_rating':'min'}).show()
# Out:
# +-------------+----------------+
# |max(duration)|min(star_rating)|
# +-------------+----------------+
# |          242|             7.4|
# +-------------+----------------+

# %%
df1 = spark.read.csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\Churn Modeling.csv", header = True, inferSchema = True)

# %%
df1.show()
# Out:
# +---------+----------+---------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+------+
# |RowNumber|CustomerId|  Surname|CreditScore|Geography|Gender|Age|Tenure|  Balance|NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|Exited|
# +---------+----------+---------+-----------+---------+------+---+------+---------+-------------+---------+--------------+---------------+------+
# |        1|  15634602| Hargrave|        619|   France|Female| 42|     2|      0.0|            1|        1|             1|      101348.88|     1|
# |        2|  15647311|     Hill|        608|    Spain|Female| 41|     1| 83807.86|            1|        0|             1|      112542.58|     0|
# |        3|  15619304|     Onio|        502|   France|Female| 42|     8| 159660.8|            3|        1|             0|      113931.57|     1|
# ...

# %%
df1.join(df,df1.Surname==df.genre).show()
# Out:
# +---------+----------+-------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+------+-----------+-----+--------------+-----+--------+-----------+
# |RowNumber|CustomerId|Surname|CreditScore|Geography|Gender|Age|Tenure|Balance|NumOfProducts|HasCrCard|IsActiveMember|EstimatedSalary|Exited|star_rating|title|content_rating|genre|duration|actors_list|
# +---------+----------+-------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+------+-----------+-----+--------------+-----+--------+-----------+
# +---------+----------+-------+-----------+---------+------+---+------+-------+-------------+---------+--------------+---------------+------+-----------+-----+--------------+-----+--------+-----------+

# %%
df.groupBy('genre').count().show()
# Out:
# +---------+-----+
# |    genre|count|
# +---------+-----+
# |    Crime|  124|
# | Thriller|    5|
# |Adventure|   75|
# |    Drama|  278|
# |   Family|    2|
# |  Fantasy|    1|
# |  History|    1|
# |  Mystery|   16|
# |Animation|   62|
# |Film-Noir|    3|
# |   Horror|   29|
# |  Western|    9|
# |Biography|   77|
# |   Comedy|  156|
# |   Action|  136|
# |   Sci-Fi|    5|
# +---------+-----+

# %%
df.groupby('genre').count().show()
# Out:
# +---------+-----+
# |    genre|count|
# +---------+-----+
# |    Crime|  124|
# | Thriller|    5|
# |Adventure|   75|
# |    Drama|  278|
# |   Family|    2|
# |  Fantasy|    1|
# |  History|    1|
# |  Mystery|   16|
# |Animation|   62|
# |Film-Noir|    3|
# |   Horror|   29|
# |  Western|    9|
# |Biography|   77|
# |   Comedy|  156|
# |   Action|  136|
# |   Sci-Fi|    5|
# +---------+-----+

# %%
df.groupBy('genre').count().show()
# Out:
# +---------+-----+
# |    genre|count|
# +---------+-----+
# |    Crime|  124|
# | Thriller|    5|
# |Adventure|   75|
# |    Drama|  278|
# |   Family|    2|
# |  Fantasy|    1|
# |  History|    1|
# |  Mystery|   16|
# |Animation|   62|
# |Film-Noir|    3|
# |   Horror|   29|
# |  Western|    9|
# |Biography|   77|
# |   Comedy|  156|
# |   Action|  136|
# |   Sci-Fi|    5|
# +---------+-----+

# %%
df.orderBy('duration').show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        8.0|              Freaks|       UNRATED|    Drama|      64|[u'Wallace Ford',...|
# |        8.0| Battleship Potemkin|       UNRATED|  History|      66|[u'Aleksandr Anto...|
# |        8.1|The Cabinet of Dr...|       UNRATED|    Crime|      67|[u'Werner Krauss'...|
# |        8.4|             The Kid|     NOT RATED|   Comedy|      68|[u'Charles Chapli...|
# |        8.1|           Duck Soup|        PASSED|   Comedy|      68|[u'Groucho Marx',...|
# |        7.6|           Following|             R|  Mystery|      69|[u'Jeremy Theobal...|
# |        8.0|        Frankenstein|       UNRATED|   Horror|      70|[u'Colin Clive', ...|
# ...

# %%
df.sort(df.star_rating.desc()).show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|          Fight Club|             R|    Drama|     139|[u'Brad Pitt', u'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# ...

# %%
df.sort(df.duration.desc()).show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        7.8|              Hamlet|         PG-13|    Drama|     242|[u'Kenneth Branag...|
# |        8.2|  Gone with the Wind|             G|    Drama|     238|[u'Clark Gable', ...|
# |        8.4|Once Upon a Time ...|             R|    Crime|     229|[u'Robert De Niro...|
# |        8.3|Lagaan: Once Upon...|            PG|Adventure|     224|[u'Aamir Khan', u...|
# |        7.9|The Ten Commandments|      APPROVED|Adventure|     220|[u'Charlton Hesto...|
# |        8.4|  Lawrence of Arabia|            PG|Adventure|     216|"[u""Peter O'Toole""|
# |        8.1|             Ben-Hur|             G|Adventure|     212|[u'Charlton Hesto...|
# ...

# %%
df2 = df.withColumn('new_duration',df.duration/2)

# %%
df2.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|new_duration|
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|        71.0|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|        87.5|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|       100.0|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|        76.0|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|        77.0|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|        48.0|
# ...

# %%
df2.drop('new_duration').show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|
# +-----------+--------------------+--------------+---------+--------+--------------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|
# |        8.9|The Good, the Bad...|     NOT RATED|  Western|     161|[u'Clint Eastwood...|
# ...

# %%
df2.show()
# Out:
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |star_rating|               title|content_rating|    genre|duration|         actors_list|new_duration|
# +-----------+--------------------+--------------+---------+--------+--------------------+------------+
# |        9.3|The Shawshank Red...|             R|    Crime|     142|[u'Tim Robbins', ...|        71.0|
# |        9.2|       The Godfather|             R|    Crime|     175|[u'Marlon Brando'...|        87.5|
# |        9.1|The Godfather: Pa...|             R|    Crime|     200|[u'Al Pacino', u'...|       100.0|
# |        9.0|     The Dark Knight|         PG-13|   Action|     152|[u'Christian Bale...|        76.0|
# |        8.9|        Pulp Fiction|             R|    Crime|     154|[u'John Travolta'...|        77.0|
# |        8.9|        12 Angry Men|     NOT RATED|    Drama|      96|[u'Henry Fonda', ...|        48.0|
# ...

# %%
df.collect()
# Out:
# [Row(star_rating=9.3, title='The Shawshank Redemption', content_rating='R', genre='Crime', duration=142, actors_list="[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"),
#  Row(star_rating=9.2, title='The Godfather', content_rating='R', genre='Crime', duration=175, actors_list="[u'Marlon Brando', u'Al Pacino', u'James Caan']"),
#  Row(star_rating=9.1, title='The Godfather: Part II', content_rating='R', genre='Crime', duration=200, actors_list="[u'Al Pacino', u'Robert De Niro', u'Robert Duvall']"),
#  Row(star_rating=9.0, title='The Dark Knight', content_rating='PG-13', genre='Action', duration=152, actors_list="[u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']"),
#  Row(star_rating=8.9, title='Pulp Fiction', content_rating='R', genre='Crime', duration=154, actors_list="[u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']"),
# ...

# %%
len(df.collect())
# Out:
# 979
