# %% [markdown]
# ## Different ways to create Pandas DataFrame

# %% [markdown]
# #### 1. Reading data from csv

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\bengaluru_house_prices.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 2. Reading Data from Excel

# %%
df1 = pd.read_excel(r"C:\Users\Roshan B\Desktop\ML\Dataset\demo.xlsx")

# %%
df1
# Out:
#    id     name   city
# 0   0     ndss  t1fsd
# 1   1  ;smdvns   fsdm
# 2   2   fsvsjn     kd
# 3   3   kffksn     md
# 4   4     mksd     dm
# 5   5     ksdk    mkd
# 6   6   ksdkvs     kd
# 7   7   vsdmks   mksd
# 8   8       lk   leti

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.read_excel(r"C:\Users\Roshan B\Desktop\ML\Dataset\demo1.xlsx")

# %%
df2
# Out:
#                  Name                       Position         Office  Age  \
# 0          Airi Satou                     Accountant          Tokyo   33
# 1      Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2          Ashton Cox        Junior Technical Author  San Francisco   66
# 3       Bradley Greer              Software Engineer         London   41
# 4      Brenden Wagner              Software Engineer  San Francisco   28
# 5  Brielle Williamson         Integration Specialist       New York   61
# 6          Bruno Nash              Software Engineer         London   38
# 7        Caesar Vance              Pre-Sales Support       New York   21
# 8        Cara Stevens                Sales Assistant       New York   46
# 9        Cedric Kelly    Senior Javascript Developer      Edinburgh   22
#
#   Start date      Salary
# 0 2008-11-28    $162,700
# 1 2009-10-09  $1,200,000
# 2 2009-01-12     $86,000
# 3 2012-10-13    $132,000
# 4 2011-06-07    $206,850
# ...

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 3. Create Dataframe from Dict.

# %%
py_dict = {
    'Name': ['Roshan','Sandip','Rakesh','Ajay'],
    'Age' : [25,31,24,28],
    'City' : ['Aurangabad','Mumbai','Nagpur','Pune']
}

# %%
df3  = pd.DataFrame(py_dict)

# %%
df3
# Out:
#      Name  Age        City
# 0  Roshan   25  Aurangabad
# 1  Sandip   31      Mumbai
# 2  Rakesh   24      Nagpur
# 3    Ajay   28        Pune

# %%
py_fruits = {
    'Fruits_list':['Apple','Banana','Grapes'],
    'Price':[450,250,300],
    'Color':['Red','Yellow','Green']
}

# %%
df4 = pd.DataFrame(py_fruits)

# %%
df4
# Out:
#   Fruits_list  Price   Color
# 0       Apple    450     Red
# 1      Banana    250  Yellow
# 2      Grapes    300   Green

# %%
df4['Fruits_list']
# Out:
# 0     Apple
# 1    Banana
# 2    Grapes
# Name: Fruits_list, dtype: object

# %%
py_dict1 = [
    {'Id':101,'Name':'Roshan','Salary':45000},
    {'Id':102,'Name':'Kunal','Salary':35400},
    {'Id':103,'Name':'Mohan','Salary':65400}
]

# %%
df5 = pd.DataFrame(py_dict1)

# %%
df5
# Out:
#     Id    Name  Salary
# 0  101  Roshan   45000
# 1  102   Kunal   35400
# 2  103   Mohan   65400

# %% [markdown]
# #### 3. Create Dataframe from API.

# %%
df6 = pd.read_json('https://api.sampleapis.com/beers/ale')

# %%
df6
# Out:
#       price                                             name  \
# 0    $16.99                             Founders All Day IPA
# 1    $13.99  Blue Moon Belgian White Belgian-Style Wheat Ale
# 2    $16.99                             Guinness Extra Stout
# 3     $8.99                             Guinness Extra Stout
# 4    $15.49                           Sierra Nevada Pale Ale
# ..      ...                                              ...
# 177  $13.99  Blue Moon Belgian White Belgian-Style Wheat Ale
# 178   $9.99                             Founders All Day IPA
# 179  $11.99                   Chimay Cinq Cents White Triple
# 180  $11.99                                           Surbhi
# 181  $11.99                                            Singh
#
#                                               rating  \
# 0     {'average': 4.411243509154233, 'reviews': 453}
# 1    {'average': 4.7752608333834825, 'reviews': 305}
# 2     {'average': 3.978596147459463, 'reviews': 119}
# ...

# %%
df7 = pd.read_json('https://api.sampleapis.com/countries/countries')

# %%
df7
# Out:
#     abbreviation      capital currency                    name phone  \
# 0             BD        Dhaka      BDT              Bangladesh   880
# 1             BE     Brussels      EUR                 Belgium    32
# 2             BF  Ouagadougou      XOF            Burkina Faso   226
# 3             BG        Sofia      BGN                Bulgaria   359
# 4             BA     Sarajevo      BAM  Bosnia and Herzegovina   387
# ..           ...          ...      ...                     ...   ...
# 245           IE       Dublin      EUR                 Ireland   353
# 246           ID      Jakarta      IDR               Indonesia    62
# 247           UA         Kiev      UAH                 Ukraine   380
# 248           QA         Doha      QAR                   Qatar   974
# 249           MZ       Maputo      MZN              Mozambique   258
#
#       population                                              media   id
# ...

# %%
df8 = pd.read_json('https://api.sampleapis.com/bitcoin/historical_prices')

# %%
df8
# Out:
#           Date    Price     Open     High  ChangePercentFromLastMonth   Volume
# 0   2022-01-01  41321.0  46217.5  47944.9                      -10.60  517.02K
# 1   2021-12-01  46219.5  56891.7  59064.3                      -18.75    1.90M
# 2   2021-11-01  56882.9  61310.1  68990.6                       -7.22    1.85M
# 3   2021-10-01  61309.6  43824.4  66967.1                       39.90    2.18M
# 4   2021-09-01  43823.3  47129.2  52885.3                       -7.02    2.21M
# ..         ...      ...      ...      ...                         ...      ...
# 133 2010-12-01      0.3      0.2      0.3                       44.09  263.65K
# 134 2010-11-01      0.2      0.2      0.5                        0.00  826.25K
# 135 2010-10-01      0.2      0.1      0.2                      210.99    1.11M
# 136 2010-09-01      0.1      0.1      0.2                        0.00  216.81K
# 137 2010-08-01      0.1      0.1      0.1                        0.00  221.74K
#
# [138 rows x 6 columns]

# %%
df9 = pd.read_json('https://api.publicapis.org/entries')

# %%
df9
# Out:
#       count                                            entries
# 0      1425  {'API': 'AdoptAPet', 'Description': 'Resource ...
# 1      1425  {'API': 'Axolotl', 'Description': 'Collection ...
# 2      1425  {'API': 'Cat Facts', 'Description': 'Daily cat...
# 3      1425  {'API': 'Cataas', 'Description': 'Cat as a ser...
# 4      1425  {'API': 'Cats', 'Description': 'Pictures of ca...
# ...     ...                                                ...
# 1420   1425  {'API': 'Visual Crossing', 'Description': 'Glo...
# 1421   1425  {'API': 'weather-api', 'Description': 'A RESTf...
# 1422   1425  {'API': 'WeatherAPI', 'Description': 'Weather ...
# 1423   1425  {'API': 'Weatherbit', 'Description': 'Weather'...
# 1424   1425  {'API': 'Yandex.Weather', 'Description': 'Asse...
#
# [1425 rows x 2 columns]

# %%
import requests

# %%
r = requests.get('https://www.mapsofindia.com/states/')

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\n<head>\n<title>Attention Required! | Cloudflare</title>\n<meta charset="UTF-8" />\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta name="robots" content="noindex, nofollow" />\n<meta name="viewport" content="width=device-width,initial-scale=1" />\n<link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />\n<!--[if lt IE 9]><link rel="stylesheet" id=\'cf_styles-ie-css\' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->\n<style>body{margin:0;padding:0}</style>\n\n\n<!--[if gte IE 10]><!-->\n<script>\n  if (!navigator.cookieEnabled) {\n    window.addEventList
# ...

# %%
df = pd.read_json('https://www.mapsofindia.com/')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [142], in <cell line: 1>()
# ----> 1 df = pd.read_json('https://www.mapsofindia.com/')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\DS_data_set_analysis.csv")

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.shape
# Out:
# (94867, 60)

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df[["iso_code","location","date","total_cases","new_cases","new_cases_smoothed"]]
# Out:
#       iso_code     location        date  total_cases  new_cases  \
# 0          AFG  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG  Afghanistan  28/02/2020          1.0        0.0
# ...        ...          ...         ...          ...        ...
# 94862      ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# ...

# %%
df[['location','date','iso_code']]
# Out:
#           location        date iso_code
# 0      Afghanistan  24/02/2020      AFG
# 1      Afghanistan  25/02/2020      AFG
# 2      Afghanistan  26/02/2020      AFG
# 3      Afghanistan  27/02/2020      AFG
# 4      Afghanistan  28/02/2020      AFG
# ...            ...         ...      ...
# 94862     Zimbabwe  06/06/2021      ZWE
# 94863     Zimbabwe  07/06/2021      ZWE
# 94864     Zimbabwe  08/06/2021      ZWE
# 94865     Zimbabwe  09/06/2021      ZWE
# 94866     Zimbabwe  10/06/2021      ZWE
#
# [94867 rows x 3 columns]

# %%
df.location
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 94862       Zimbabwe
# 94863       Zimbabwe
# 94864       Zimbabwe
# 94865       Zimbabwe
# 94866       Zimbabwe
# Name: location, Length: 94867, dtype: object

# %%
col_list = [col for col in df.columns if col.startswith('new')]

# %%
col_list
# Out:
# ['new_cases',
#  'new_cases_smoothed',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'new_tests',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'new_vaccinations',
#  'new_vaccinations_smoothed',
#  'new_vaccinations_smoothed_per_million']

# %%
df[col_list]
# Out:
#        new_cases  new_cases_smoothed  new_deaths  new_deaths_smoothed  \
# 0            1.0                 NaN         NaN                  NaN
# 1            0.0                 NaN         NaN                  NaN
# 2            0.0                 NaN         NaN                  NaN
# 3            0.0                 NaN         NaN                  NaN
# 4            0.0                 NaN         NaN                  NaN
# ...          ...                 ...         ...                  ...
# 94862       21.0              35.000         1.0                1.714
# 94863       49.0              39.571         5.0                2.429
# 94864       83.0              46.143         6.0                2.571
# 94865      111.0              57.286         5.0                3.286
# 94866       64.0              57.714         4.0                3.143
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# 0                      0.026                             NaN
# ...

# %%
df.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94867 entries, 0 to 94866
# Data columns (total 60 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               94867 non-null  object
#  1   continent                              90387 non-null  object
#  2   location                               94867 non-null  object
#  3   date                                   94867 non-null  object
#  4   total_cases                            91760 non-null  float64
#  5   new_cases                              91757 non-null  float64
#  6   new_cases_smoothed                     90747 non-null  float64
#  7   total_deaths                           81781 non-null  float64
#  8   new_deaths                             81937 non-null  float64
#  9   new_deaths_smoothed                    90747 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.176000e+04   91757.000000        90747.000000  8.178100e+04
# mean   9.823545e+05    6059.404253         6086.950436  2.703805e+04
# std    6.765660e+06   38082.374634        37832.857208  1.610378e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.148000e+03       2.000000            7.286000  5.100000e+01
# 50%    1.257150e+04      72.000000           90.143000  3.520000e+02
# 75%    1.323872e+05     797.000000          835.714000  3.454000e+03
# max    1.748673e+08  906008.000000       826389.571000  3.773339e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  81937.000000         90747.000000             91270.000000
# mean     147.089288           131.678010             12072.139046
# std      804.364326           743.874762             22560.724598
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
len(df['location'].unique())
# Out:
# 229

# %%
df['location'].value_counts()
# Out:
# Mexico                             527
# Argentina                          527
# Thailand                           524
# Peru                               522
# Taiwan                             512
#                                   ...
# Kiribati                            24
# Cook Islands                        15
# British Virgin Islands               8
# Bonaire Sint Eustatius and Saba      1
# Turkmenistan                         1
# Name: location, Length: 229, dtype: int64

# %%
df['test'] = 100

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.shape
# Out:
# (94867, 61)

# %%
df[['continent','location']]
# Out:
#       continent     location
# 0          Asia  Afghanistan
# 1          Asia  Afghanistan
# 2          Asia  Afghanistan
# 3          Asia  Afghanistan
# 4          Asia  Afghanistan
# ...         ...          ...
# 94862    Africa     Zimbabwe
# 94863    Africa     Zimbabwe
# 94864    Africa     Zimbabwe
# 94865    Africa     Zimbabwe
# 94866    Africa     Zimbabwe
#
# [94867 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %%
df.shape
# Out:
# (94867, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94867 entries, 0 to 94866
# Data columns (total 61 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               94867 non-null  object
#  1   continent                              90387 non-null  object
#  2   location                               94867 non-null  object
#  3   date                                   94867 non-null  object
#  4   total_cases                            91760 non-null  float64
#  5   new_cases                              91757 non-null  float64
#  6   new_cases_smoothed                     90747 non-null  float64
#  7   total_deaths                           81781 non-null  float64
#  8   new_deaths                             81937 non-null  float64
#  9   new_deaths_smoothed                    90747 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  9.176000e+04   91757.000000        90747.000000  8.178100e+04
# mean   9.823545e+05    6059.404253         6086.950436  2.703805e+04
# std    6.765660e+06   38082.374634        37832.857208  1.610378e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    1.148000e+03       2.000000            7.286000  5.100000e+01
# 50%    1.257150e+04      72.000000           90.143000  3.520000e+02
# 75%    1.323872e+05     797.000000          835.714000  3.454000e+03
# max    1.748673e+08  906008.000000       826389.571000  3.773339e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  81937.000000         90747.000000             91270.000000
# mean     147.089288           131.678010             12072.139046
# std      804.364326           743.874762             22560.724598
# min    -1918.000000          -232.143000                 0.001000
# ...

# %%
df['test'] = df['continent'] + df['iso_code']

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...
