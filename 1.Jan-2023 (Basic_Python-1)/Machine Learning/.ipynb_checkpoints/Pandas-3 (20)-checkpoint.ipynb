# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv")   # Read CSV file

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.sort_index(axis=1)    # sorting column in ascending order
# Out:
#                                            actors_list content_rating  \
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              R
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...          PG-13
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              R
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...             PG
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...             PG
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...          PG-13
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...             PG
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              R
#
#      duration      genre  star_rating  \
# 0         142      Crime          9.3
# 1         175      Crime          9.2
# ...

# %%
df.sort_index(ascending = False)     # sorting Row in descending  order to index column
# Out:
#      star_rating                                            title  \
# 978          7.4                                      Wall Street
# 977          7.4                                      Poltergeist
# 976          7.4  Master and Commander: The Far Side of the World
# 975          7.4                      Back to the Future Part III
# 974          7.4                                          Tootsie
# ..           ...                                              ...
# 4            8.9                                     Pulp Fiction
# 3            9.0                                  The Dark Knight
# 2            9.1                           The Godfather: Part II
# 1            9.2                                    The Godfather
# 0            9.3                         The Shawshank Redemption
#
#     content_rating      genre  duration  \
# 978              R      Crime       126
# 977             PG     Horror       114
# 976          PG-13     Action       138
# ...

# %%
df.sort_values(['genre'])     # Ascending order to genre column(perticular column)
# Out:
#      star_rating                   title content_rating    genre  duration  \
# 152          8.2          V for Vendetta              R   Action       132
# 753          7.6    Escape from Alcatraz             PG   Action       112
# 619          7.7        Forbidden Planet         PASSED   Action        98
# 129          8.3                     Ran              R   Action       162
# 871          7.5                      X2          PG-13   Action       134
# ..           ...                     ...            ...      ...       ...
# 263          8.1               Rio Bravo      NOT RATED  Western       141
# 236          8.1               High Noon             PG  Western        85
# 119          8.3              Unforgiven              R  Western       131
# 421          7.9  The Outlaw Josey Wales             PG  Western       135
# 704          7.6     High Plains Drifter              R  Western       105
#
#                                            actors_list
# ...

# %%
df.sort_values(['genre'],ascending=False)      # Descending order to genre column
# Out:
#      star_rating                               title content_rating    genre  \
# 107          8.3              For a Few Dollars More       APPROVED  Western
# 421          7.9              The Outlaw Josey Wales             PG  Western
# 704          7.6                 High Plains Drifter              R  Western
# 6            8.9      The Good, the Bad and the Ugly      NOT RATED  Western
# 26           8.6        Once Upon a Time in the West          PG-13  Western
# ..           ...                                 ...            ...      ...
# 118          8.3  Indiana Jones and the Last Crusade          PG-13   Action
# 586          7.7     Star Trek II: The Wrath of Khan             PG   Action
# 581          7.8                         Man on Fire              R   Action
# 113          8.3                       Batman Begins          PG-13   Action
# 420          7.9           The Man Who Would Be King             PG   Action
#
# ...

# %%
df.sort_values(['star_rating'])     # by default ascending order, for decending add (ascending = False)
# Out:
#      star_rating                           title content_rating    genre  \
# 978          7.4                     Wall Street              R    Crime
# 950          7.4                           Bound              R    Crime
# 949          7.4                      Home Alone             PG   Comedy
# 948          7.4                      Frances Ha              R   Comedy
# 947          7.4                      Eraserhead        UNRATED    Drama
# ..           ...                             ...            ...      ...
# 6            8.9  The Good, the Bad and the Ugly      NOT RATED  Western
# 3            9.0                 The Dark Knight          PG-13   Action
# 2            9.1          The Godfather: Part II              R    Crime
# 1            9.2                   The Godfather              R    Crime
# 0            9.3        The Shawshank Redemption              R    Crime
#
#      duration                                        actors_list
# ...

# %%
df.sort_values(['duration'])
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.iloc[100]    # fetch record 100 nth index number by using iloc
# Out:
# star_rating                                                     8.3
# title                              The Treasure of the Sierra Madre
# content_rating                                            NOT RATED
# genre                                                        Action
# duration                                                        126
# actors_list       [u'Humphrey Bogart', u'Walter Huston', u'Tim H...
# Name: 100, dtype: object

# %%
df.iloc[1:4]    # fetch record from 1 to 4 index
# Out:
#    star_rating                   title content_rating   genre  duration  \
# 1          9.2           The Godfather              R   Crime       175
# 2          9.1  The Godfather: Part II              R   Crime       200
# 3          9.0         The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
df.reset_index(inplace = True)      # reset index to original

# %%
df
# Out:
#      index  star_rating                                            title  \
# 0        0          9.3                         The Shawshank Redemption
# 1        1          9.2                                    The Godfather
# 2        2          9.1                           The Godfather: Part II
# 3        3          9.0                                  The Dark Knight
# 4        4          8.9                                     Pulp Fiction
# ..     ...          ...                                              ...
# 974    974          7.4                                          Tootsie
# 975    975          7.4                      Back to the Future Part III
# 976    976          7.4  Master and Commander: The Far Side of the World
# 977    977          7.4                                      Poltergeist
# 978    978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# ...

# %%
df.drop('actors_list',axis = 1)       # delete single column
# Out:
#      index  star_rating                                            title  \
# 0        0          9.3                         The Shawshank Redemption
# 1        1          9.2                                    The Godfather
# 2        2          9.1                           The Godfather: Part II
# 3        3          9.0                                  The Dark Knight
# 4        4          8.9                                     Pulp Fiction
# ..     ...          ...                                              ...
# 974    974          7.4                                          Tootsie
# 975    975          7.4                      Back to the Future Part III
# 976    976          7.4  Master and Commander: The Far Side of the World
# 977    977          7.4                                      Poltergeist
# 978    978          7.4                                      Wall Street
#
#     content_rating      genre  duration
# 0                R      Crime       142
# ...

# %%
df
# Out:
#      index  star_rating                                            title  \
# 0        0          9.3                         The Shawshank Redemption
# 1        1          9.2                                    The Godfather
# 2        2          9.1                           The Godfather: Part II
# 3        3          9.0                                  The Dark Knight
# 4        4          8.9                                     Pulp Fiction
# ..     ...          ...                                              ...
# 974    974          7.4                                          Tootsie
# 975    975          7.4                      Back to the Future Part III
# 976    976          7.4  Master and Commander: The Far Side of the World
# 977    977          7.4                                      Poltergeist
# 978    978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# ...

# %%
df.drop(columns = ['actors_list','content_rating'],axis = 1)         # delete multiple column
# Out:
#      index  star_rating                                            title  \
# 0        0          9.3                         The Shawshank Redemption
# 1        1          9.2                                    The Godfather
# 2        2          9.1                           The Godfather: Part II
# 3        3          9.0                                  The Dark Knight
# 4        4          8.9                                     Pulp Fiction
# ..     ...          ...                                              ...
# 974    974          7.4                                          Tootsie
# 975    975          7.4                      Back to the Future Part III
# 976    976          7.4  Master and Commander: The Far Side of the World
# 977    977          7.4                                      Poltergeist
# 978    978          7.4                                      Wall Street
#
#          genre  duration
# 0        Crime       142
# 1        Crime       175
# ...

# %%
df1 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\bengaluru_house_prices.csv")

# %%
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df = pd.read_excel('Georgia_Population.xlsx')

# %%
df
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly  Change  \
# 0            0  2020     3989167         -0.19 %         -7598.0
# 1            1  2019     3996765             NaN             NaN
# 2            2  2018     4002942         -0.14 %         -5774.0
# 3            3  2017     4008716         -0.17 %         -6734.0
# 4            4  2016     4015450         -0.22 %         -8733.0
# 5            5  2015     4024183         -0.37 %        -14983.0
# 6            6  2010     4099099         -0.53 %        -22214.0
# 7            7  2005     4210168         -0.71 %             NaN
# 8            8  2000     4362187         -2.60 %       -122815.0
# 9            9  1995     4976260         -1.66 %        -86828.0
# 10          10  1990     5410399          0.75 %         39789.0
# 11          11  1985     5211454          0.76 %         38724.0
# 12          12  1980     5017833          0.58 %         28839.0
# ...

# %%
df.dropna()
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly  Change  \
# 0            0  2020     3989167         -0.19 %         -7598.0
# 3            3  2017     4008716         -0.17 %         -6734.0
# 5            5  2015     4024183         -0.37 %        -14983.0
# 6            6  2010     4099099         -0.53 %        -22214.0
# 8            8  2000     4362187         -2.60 %       -122815.0
# 9            9  1995     4976260         -1.66 %        -86828.0
# 10          10  1990     5410399          0.75 %         39789.0
# 11          11  1985     5211454          0.76 %         38724.0
# 12          12  1980     5017833          0.58 %         28839.0
# 13          13  1975     4873639          0.67 %         32059.0
# 14          14  1970     4713342          1.52 %         68363.0
# 15          15  1965     4371527          1.75 %         72761.0
# 17          17  1955     3713133          1.03 %         37225.0
#
# ...

# %%
df.dropna(thresh=2)
# Out:
#     Unnamed: 0  Year  Population Yearly % Change  Yearly  Change  \
# 0            0  2020     3989167         -0.19 %         -7598.0
# 1            1  2019     3996765             NaN             NaN
# 2            2  2018     4002942         -0.14 %         -5774.0
# 3            3  2017     4008716         -0.17 %         -6734.0
# 4            4  2016     4015450         -0.22 %         -8733.0
# 5            5  2015     4024183         -0.37 %        -14983.0
# 6            6  2010     4099099         -0.53 %        -22214.0
# 7            7  2005     4210168         -0.71 %             NaN
# 8            8  2000     4362187         -2.60 %       -122815.0
# 9            9  1995     4976260         -1.66 %        -86828.0
# 10          10  1990     5410399          0.75 %         39789.0
# 11          11  1985     5211454          0.76 %         38724.0
# 12          12  1980     5017833          0.58 %         28839.0
# ...

# %%
df1 = df.set_index('Median Age')

# %%
df1
# Out:
#             Unnamed: 0  Year  Population Yearly % Change  Yearly  Change  \
# Median Age
# 38.3                 0  2020     3989167         -0.19 %         -7598.0
# 37.8                 1  2019     3996765             NaN             NaN
# NaN                  2  2018     4002942         -0.14 %         -5774.0
# 37.8                 3  2017     4008716         -0.17 %         -6734.0
# 37.8                 4  2016     4015450         -0.22 %         -8733.0
# 37.7                 5  2015     4024183         -0.37 %        -14983.0
# 37.7                 6  2010     4099099         -0.53 %        -22214.0
# NaN                  7  2005     4210168         -0.71 %             NaN
# 34.7                 8  2000     4362187         -2.60 %       -122815.0
# 32.8                 9  1995     4976260         -1.66 %        -86828.0
# 31.0                10  1990     5410399          0.75 %         39789.0
# 29.8                11  1985     5211454          0.76 %         38724.0
# ...

# %%
df1= df.set_index('genre')

# %%
df1.drop('Crime')
# Out:
#            star_rating                                            title  \
# genre
# Action             9.0                                  The Dark Knight
# Drama              8.9                                     12 Angry Men
# Western            8.9                   The Good, the Bad and the Ugly
# Adventure          8.9    The Lord of the Rings: The Return of the King
# Biography          8.9                                 Schindler's List
# ...                ...                                              ...
# Drama              7.4                            The Cider House Rules
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
#
#           content_rating  duration  \
# genre
# Action             PG-13       152
# ...

# %%
py_dict = {
    'id':[101,102,103,104,105],
    'name':['A','B','C','D','E'],
    'sal':[4500,6555,6566,4588,25655],
    'city':['pune','mumbai','nagpur','aurangabad','goa']
}

# %%
df2 = pd.DataFrame(py_dict)

# %%
df2
# Out:
#     id name    sal        city
# 0  101    A   4500        pune
# 1  102    B   6555      mumbai
# 2  103    C   6566      nagpur
# 3  104    D   4588  aurangabad
# 4  105    E  25655         goa

# %%
df2.loc[[1,3,4],['id','city']]
# Out:
#     id        city
# 1  102      mumbai
# 3  104  aurangabad
# 4  105         goa

# %%
df2.loc[[0,3],['id','name','city']]
# Out:
#     id name        city
# 0  101    A        pune
# 3  104    D  aurangabad

# %%
df2.loc[0:3,'name':'city']
# Out:
#   name   sal        city
# 0    A  4500        pune
# 1    B  6555      mumbai
# 2    C  6566      nagpur
# 3    D  4588  aurangabad

# %%
df2.loc[2:4,'id':'sal']
# Out:
#     id name    sal
# 2  103    C   6566
# 3  104    D   4588
# 4  105    E  25655

# %%
df2.loc[[2,4],['id','city']]
# Out:
#     id    city
# 2  103  nagpur
# 4  105     goa

# %%
df2
# Out:
#     id name    sal        city
# 0  101    A   4500        pune
# 1  102    B   6555      mumbai
# 2  103    C   6566      nagpur
# 3  104    D   4588  aurangabad
# 4  105    E  25655         goa

# %%
df3 = df2.set_index('city')

# %%
df3.loc[['pune','mumbai']]
# Out:
#          id name   sal
# city
# pune    101    A  4500
# mumbai  102    B  6555

# %%
df2
# Out:
#     id name    sal        city
# 0  101    A   4500        pune
# 1  102    B   6555      mumbai
# 2  103    C   6566      nagpur
# 3  104    D   4588  aurangabad
# 4  105    E  25655         goa

# %%
df2.iloc[:,1:3]
# Out:
#   name    sal
# 0    A   4500
# 1    B   6555
# 2    C   6566
# 3    D   4588
# 4    E  25655

# %%
df2.iloc[1:3,]
# Out:
#     id name   sal    city
# 1  102    B  6555  mumbai
# 2  103    C  6566  nagpur

# %%
df2.iloc[0:3,1:3]
# Out:
#   name   sal
# 0    A  4500
# 1    B  6555
# 2    C  6566

# %%
import numpy as np

# %%
s = pd.Series([1,3,5, np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20230101',periods=12)

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
df4 = pd.DataFrame(dates)

# %%
df4
# Out:
#             0
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12

# %%
df5 = pd.DataFrame(np.random.randn(12,4),index=dates,columns=list('ABCD'))

# %%
df5
# Out:
#                    A         B         C         D
# 2023-01-01  0.563204 -0.555376 -0.685650 -0.848551
# 2023-01-02  1.424324 -0.594841 -1.135757 -1.344498
# 2023-01-03 -0.463794  0.346428  0.808577 -0.411939
# 2023-01-04  0.656666  0.427874 -0.844554 -0.008807
# 2023-01-05 -0.974262  0.996194  1.675927 -0.458317
# 2023-01-06 -0.415483  0.956806  1.341822 -0.879748
# 2023-01-07 -0.245373 -2.299484  0.703624  0.122500
# 2023-01-08 -1.111338 -1.513522 -0.566123 -0.137493
# 2023-01-09  0.955309 -0.500569  1.557452  1.393741
# 2023-01-10 -0.465656 -0.598616 -1.698443 -0.798211
# 2023-01-11  0.714894 -1.185333  1.729074  0.967106
# 2023-01-12 -0.163401 -0.498102 -0.004771  0.844675

# %%
df2
# Out:
#     id name    sal        city
# 0  101    A   4500        pune
# 1  102    B   6555      mumbai
# 2  103    C   6566      nagpur
# 3  104    D   4588  aurangabad
# 4  105    E  25655         goa

# %%
df2.iloc[2:3,1:3]
# Out:
#   name   sal
# 2    C  6566

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df6 = df.loc[1:50,'star_rating':'duration']

# %%
df7 = df6.set_index('content_rating')

# %%
df7.loc['PG-13']
# Out:
#                 star_rating  \
# content_rating
# PG-13                   9.0
# PG-13                   8.9
# PG-13                   8.8
# PG-13                   8.8
# PG-13                   8.8
# PG-13                   8.8
# PG-13                   8.7
# PG-13                   8.6
# PG-13                   8.6
# PG-13                   8.5
#
#                                                             title      genre  \
# content_rating
# PG-13                                             The Dark Knight     Action
# PG-13               The Lord of the Rings: The Return of the King  Adventure
# PG-13           The Lord of the Rings: The Fellowship of the Ring  Adventure
# PG-13                                                   Inception     Action
# PG-13                                                Forrest Gump      Drama
# PG-13                       The Lord of the Rings: The Two Towers  Adventure
# ...

# %%
df7
# Out:
#                 star_rating  \
# content_rating
# R                       9.2
# R                       9.1
# PG-13                   9.0
# R                       8.9
# NOT RATED               8.9
# NOT RATED               8.9
# PG-13                   8.9
# R                       8.9
# R                       8.9
# PG-13                   8.8
# PG-13                   8.8
# PG                      8.8
# PG-13                   8.8
# PG-13                   8.8
# PG-13                   8.7
# R                       8.7
# UNRATED                 8.7
# R                       8.7
# PG                      8.7
# R                       8.7
# R                       8.7
# APPROVED                8.7
# R                       8.7
# R                       8.7
# PG-13                   8.6
# PG-13                   8.6
# R                       8.6
# R                       8.6
# PASSED                  8.6
# PG                      8.6
# R                       8.6
# ...
