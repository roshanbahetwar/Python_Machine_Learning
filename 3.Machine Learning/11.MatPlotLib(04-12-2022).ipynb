# %%
from matplotlib import pyplot as plt
# import matplotlib.pyplot as plt

# %%
# 1. Scatter Plot :- find relation between two variables. 
#   (three types of relation 1. positive( +, strongly co-relation)
#                            2. negative(-, negative co-relation)
#                            3. polynomial(no relation)

# %%
age = [18,15,20,16,20,22,24,22]
salary = [15000,16000,25000,35000,35000,24500,23500,35555]

# %%
plt.scatter(age,salary)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6AE2-CADB
#
#  Directory of C:\Users\Roshan B\Desktop\ML\Practice-2023\GitHub_Practice\Python_June2023\3.Machine Learning
#
# 29-11-2023  10:06    <DIR>          .
# 22-10-2023  09:20    <DIR>          ..
# 27-11-2023  20:55    <DIR>          .ipynb_checkpoints
# 10-10-2023  14:33            42,950 01.Pandas(18-11-2022).ipynb
# 12-10-2023  19:41           249,608 02.Pandas(19-11-2022).ipynb
# 17-10-2023  19:34           387,825 03.Pandas(20-11-2022).ipynb
# 23-10-2023  21:14           231,336 04.Pandas(22-11-2022).ipynb
# 25-10-2023  18:54            41,600 05.Pandas(23-11-2022).ipynb
# 25-10-2023  19:59            32,512 06.Pandas(24-11-2022).ipynb
# 08-11-2023  11:54           635,787 07.Pandas(from documentation).ipynb
# 09-11-2023  12:02           260,363 08.Pyspark(29-11-2023).ipynb
# 27-11-2023  19:21            33,401 09.Numpy(03-12-2022).ipynb
# 27-11-2023  20:07            31,409 10.Numpy(from documentation).ipynb
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\delhiaqi.csv")

# %%
df
# Out:
#                     date       co     no    no2     o3     so2   pm2_5  \
# 0    2023-01-01 00:00:00  1655.58   1.66  39.41   5.90   17.88  169.29
# 1    2023-01-01 01:00:00  1869.20   6.82  42.16   1.99   22.17  182.84
# 2    2023-01-01 02:00:00  2510.07  27.72  43.87   0.02   30.04  220.25
# 3    2023-01-01 03:00:00  3150.94  55.43  44.55   0.85   35.76  252.90
# 4    2023-01-01 04:00:00  3471.37  68.84  45.24   5.45   39.10  266.36
# ..                   ...      ...    ...    ...    ...     ...     ...
# 556  2023-01-24 04:00:00  1762.39   4.64  37.01  33.26   30.52  231.15
# 557  2023-01-24 05:00:00  1735.69   6.82  34.96  46.49   34.33  225.08
# 558  2023-01-24 06:00:00  1922.61   8.16  40.10  56.51   43.39  242.49
# 559  2023-01-24 07:00:00  1361.85   9.05  52.78  71.53  100.14  165.67
# 560  2023-01-24 08:00:00  1134.87   8.61  56.89  80.11  110.63  123.76
#
#        pm10    nh3
# 0    194.64   5.83
# 1    211.08   7.66
# 2    260.68  11.40
# 3    304.12  13.55
# ...

# %%
plt.scatter(df['pm2_5'],df['pm10'])

# %%
plt.scatter(df['co'],df['no2'])

# %%
plt.scatter(df['date'],df['no2'])

# %%
plt.bar(df['date'],df['no2'])
# Out:
# <BarContainer object of 561 artists>

# %%
plt.scatter(df['co'],df['pm10'])

# %%
plt.plot(df['co'])

# %%
plt.plot(df['so2'])

# %%
plt.plot(df['so2'],df['no2'])

# %%
plt.bar(df['so2'],df['no2'])
# Out:
# <BarContainer object of 561 artists>

# %%
plt.plot(df['so2'],marker = '*')

# %%
df['so2']
# Out:
# 0       17.88
# 1       22.17
# 2       30.04
# 3       35.76
# 4       39.10
#         ...
# 556     30.52
# 557     34.33
# 558     43.39
# 559    100.14
# 560    110.63
# Name: so2, Length: 561, dtype: float64

# %%
lst = {
    'value':[22.5,12.4,35.25,44,22,25.6,12.5]}

# %%
df1 = pd.DataFrame(lst)

# %%
df1
# Out:
#    value
# 0  22.50
# 1  12.40
# 2  35.25
# 3  44.00
# 4  22.00
# 5  25.60
# 6  12.50

# %%
plt.plot(df1['value'],marker = '*',markersize = 15)

# %%
plt.scatter(df['so2'],df['pm2_5'])
plt.title('Aqi')
plt.xlabel('so2')
plt.ylabel('pm2_5')
plt.legend('PM')

# %%
df['so2']
# Out:
# 0       17.88
# 1       22.17
# 2       30.04
# 3       35.76
# 4       39.10
#         ...
# 556     30.52
# 557     34.33
# 558     43.39
# 559    100.14
# 560    110.63
# Name: so2, Length: 561, dtype: float64

# %%
X = ['Python32','Python33','Python34','Python35']

girls = [35,36,40,65]
boys = [55,25,67,96]

# %%
import numpy as np
x_axis = np.arange(len(X))
x_axis
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(x_axis-0.2,boys,0.4,label = 'Boys')
plt.bar(x_axis+0.2,girls,0.4,label = 'Girls')
plt.xticks(x_axis,X)
plt.legend()

# %%
# HistoGram( Density Graph)

age_data = [15,15,16,17,12,15,16,16,20,25,28,32,20,44,47,55]

# %%
import matplotlib.pyplot as plt

plt.hist(age_data,bins = 10)
# Out:
# (array([7., 3., 0., 2., 1., 0., 0., 1., 1., 1.]),
#  array([12. , 16.3, 20.6, 24.9, 29.2, 33.5, 37.8, 42.1, 46.4, 50.7, 55. ]),
#  <BarContainer object of 10 artists>)

# %%
df['so2']
# Out:
# 0       17.88
# 1       22.17
# 2       30.04
# 3       35.76
# 4       39.10
#         ...
# 556     30.52
# 557     34.33
# 558     43.39
# 559    100.14
# 560    110.63
# Name: so2, Length: 561, dtype: float64

# %%
plt.hist(df['so2'])
# Out:
# (array([323., 164.,  38.,  17.,   9.,   2.,   3.,   2.,   0.,   3.]),
#  array([  5.25 ,  55.842, 106.434, 157.026, 207.618, 258.21 , 308.802,
#         359.394, 409.986, 460.578, 511.17 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['co'],bins = 10)
# Out:
# (array([238., 159.,  56.,  34.,  15.,  23.,  15.,   9.,   4.,   8.]),
#  array([  654.22,  2276.42,  3898.62,  5520.82,  7143.02,  8765.22,
#         10387.42, 12009.62, 13631.82, 15254.02, 16876.22]),
#  <BarContainer object of 10 artists>)

# %%
# PieChart

courses = ['Python','Java','HTML','CSS']
count = [59,150,250,75]

# %%
plt.pie(count,labels=courses,shadow=True,explode=(0.2,0,0,0),autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x222efb43160>,
# ...
#  [Text(1.22246998426653, 0.4422297339250152, 'Python'),
#   Text(-0.006471406667482252, 1.0999809638788047, 'Java'),
#   Text(-0.775526096487336, -0.7801020918233174, 'HTML'),
#   Text(0.9946474734404082, -0.4697620712431057, 'CSS')],
#  [Text(0.7522892210870954, 0.27214137472308625, '11.05%'),
#   Text(-0.003529858182263046, 0.5999896166611661, '28.09%'),
#   Text(-0.42301423444763775, -0.4255102319036276, '46.82%'),
#   Text(0.5425349855129499, -0.256233857041694, '14.04%')])

# %%
df1 = df.iloc[1:10]

# %%
df1
# Out:
#                   date       co     no    no2      o3    so2   pm2_5    pm10  \
# 1  2023-01-01 01:00:00  1869.20   6.82  42.16    1.99  22.17  182.84  211.08
# 2  2023-01-01 02:00:00  2510.07  27.72  43.87    0.02  30.04  220.25  260.68
# 3  2023-01-01 03:00:00  3150.94  55.43  44.55    0.85  35.76  252.90  304.12
# 4  2023-01-01 04:00:00  3471.37  68.84  45.24    5.45  39.10  266.36  322.80
# 5  2023-01-01 05:00:00  3578.19  64.37  55.52   14.13  44.35  276.54  336.79
# 6  2023-01-01 06:00:00  3578.19  46.94  76.09   33.26  50.54  295.40  357.07
# 7  2023-01-01 07:00:00  1468.66   9.83  47.30  105.86  68.66  158.83  182.61
# 8  2023-01-01 08:00:00  1161.58   5.81  35.99  125.89  61.99  134.39  153.47
# 9  2023-01-01 09:00:00  1161.58   4.58  36.33  134.47  65.80  133.22  152.09
#
#      nh3
# 1   7.66
# 2  11.40
# 3  13.55
# 4  14.19
# 5  16.21
# 6  19.25
# 7   7.09
# 8   5.51
# 9   6.02

# %%
plt.pie(df1['co'],labels=df1,autopct = "%1.2f%%",explode= (0,0,0.2,0,0,0,0,0,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x222f76464c0>,
# ...
#  [Text(1.0608689272798355, 0.29078706837156865, 'date'),
#   Text(0.6886533337740066, 0.8577625463273312, 'co'),
#   Text(-0.17337579662494262, 1.2883869112749737, 'no'),
#   Text(-0.9709776894095546, 0.5169161698659489, 'no2'),
#   Text(-0.9547248035176138, -0.5463520381111926, 'o3'),
#   Text(-0.02942798474772664, -1.0996062903210801, 'so2'),
#   Text(0.7049151502385607, -0.8444493063317345, 'pm2_5'),
#   Text(0.9659950227472527, -0.5261688094400265, 'pm10'),
#   Text(1.0848330230791352, -0.18203656785652914, 'nh3')],
#  [Text(0.5786557785162738, 0.15861112820267378, '8.52%'),
#   Text(0.3756290911494581, 0.46787047981490787, '11.44%'),
#   Text(-0.1066927979230416, 0.7928534838615222, '14.36%'),
#   Text(-0.5296241942233934, 0.28195427447233573, '15.82%'),
#   Text(-0.5207589837368802, -0.298010202606105, '16.30%'),
#   Text(-0.016051628044214526, -0.5997852492660437, '16.30%'),
# ...
