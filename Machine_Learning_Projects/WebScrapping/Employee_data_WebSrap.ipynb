# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
requests.get("https://www.ambitionbox.com/list-of-companies?pages%20=1")
# Out:
# <Response [403]>

# %%
requests.get("https://www.ambitionbox.com/list-of-companies?pages%20=1").text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies&#63;" on this server.<P>\nReference&#32;&#35;18&#46;2fb72c31&#46;1703391885&#46;8313236\n</BODY>\n</HTML>\n'

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
webpage = requests.get("https://www.ambitionbox.com/list-of-companies?page=1",headers=headers).text

# %%
webpage
# Out:
# '<!doctype html>\n<html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D">\n  <head >\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n    <style>@media only screen and (min-width:767px){.trp-img{width:400px!important;max-width:400px!important}}</style>\n    <script>window.dataLayer=window.dataLayer||[],window.gtag=window.gtag||function(){window.dataLayer.push(arguments)},gtag("js",new Date)</script>\n\n    <title>List of companies in India | AmbitionBox</title><meta data-n-head="ssr" name="copyright" content="2023 AmbitionBox"><meta data-n-head="ssr" name="revisit-after" content="1 day"><meta data-n-head="ssr" name="application-name" content="AmbitionBox"><meta data-n-head="ssr" name="content-language" content="EN"><meta data-n-head="ssr" name="google-signin-client_id" content="462822053404-hphug4pkahqljh2tc96g35at47o4isv2.a
# ...

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
# print(soup.prettify())

# %%
# soup.find_all('h1')[0].text

# %%
# for i in soup.find_all('h2'):
#     print((i.text).strip())

# %%
# for i in soup.find_all('p'):
#     print(i.text.strip())

# %%
# soup.find_all('a',class_="companyCardWrapper__ActionWrapper")

# %%
company = soup.find_all('div',class_= 'companyCardWrapper__primaryInformation')

# %%
company
# Out:
# [<div class="companyCardWrapper__primaryInformation"><div class="companyCardWrapper__companyDetails"><div class="companyCardWrapper__companyLogo"><img alt="Tata Consultancy Services logo" height="50" loading="lazy" onerror="this.onerror=null;this.src='/static/icons/company-placeholder.svg';" src="https://static.ambitionbox.com/assets/v2/images/rs:fit:200:200:false:false/bG9jYWw6Ly8vbG9nb3Mvb3JpZ2luYWxzL3Rjcy5qcGc.webp" width="50"/></div> <div class="companyCardWrapper__metaInformation"><div class="companyCardWrapper__header"><div class="companyCardWrapper__companyPrimaryDetails"><div class="companyCardWrapper__companyPrimaryDetailsTopSection"><a class="companyCardWrapper__companyName companyCardWrapper__companyName--m8" href="/overview/tcs-overview"><h2 class="companyCardWrapper__companyName" title="TCS">
#  										TCS
# ...

# %%
print(company[0])
# Out:
# <div class="companyCardWrapper__primaryInformation"><div class="companyCardWrapper__companyDetails"><div class="companyCardWrapper__companyLogo"><img alt="Tata Consultancy Services logo" height="50" loading="lazy" onerror="this.onerror=null;this.src='/static/icons/company-placeholder.svg';" src="https://static.ambitionbox.com/assets/v2/images/rs:fit:200:200:false:false/bG9jYWw6Ly8vbG9nb3Mvb3JpZ2luYWxzL3Rjcy5qcGc.webp" width="50"/></div> <div class="companyCardWrapper__metaInformation"><div class="companyCardWrapper__header"><div class="companyCardWrapper__companyPrimaryDetails"><div class="companyCardWrapper__companyPrimaryDetailsTopSection"><a class="companyCardWrapper__companyName companyCardWrapper__companyName--m8" href="/overview/tcs-overview"><h2 class="companyCardWrapper__companyName" title="TCS">
# 										TCS
# ...

# %%
len(company)
# Out:
# 20

# %%
name = []
ratings = []
for i in company:
    name.append(i.find('h2').text.strip())
    ratings.append(i.find_all('span',class_='companyCardWrapper__companyRatingValue')[0].text.strip())

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'Wipro',
#  'HDFC Bank',
#  'ICICI Bank',
#  'Infosys',
#  'Capgemini',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Amazon',
#  'Teleperformance',
#  'Reliance Jio',
#  'IBM',
#  'Larsen & Toubro Limited',
#  'Reliance Retail',
#  'HDB Financial Services']

# %%
ratings
# Out:
# ['3.8',
#  '4.0',
#  '3.9',
#  '3.8',
#  '3.9',
#  '4.0',
#  '3.8',
#  '3.8',
#  '3.7',
#  '3.7',
#  '3.9',
#  '3.8',
#  '3.9',
#  '4.1',
#  '3.6',
#  '3.9',
#  '4.1',
#  '4.0',
#  '3.9',
#  '4.0']

# %%
for i in company:
    print(i.find_all('span',class_='companyCardWrapper__companyRatingValue')[0].text.strip())
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 4.0
# 3.8
# 3.8
# 3.7
# 3.7
# 3.9
# 3.8
# 3.9
# 4.1
# 3.6
# 3.9
# 4.1
# 4.0
# 3.9
# 4.0

# %%
for i in company:
    print(i.find('span',class_='companyCardWrapper__companyRatingValue').text.strip())
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 4.0
# 3.8
# 3.8
# 3.7
# 3.7
# 3.9
# 3.8
# 3.9
# 4.1
# 3.6
# 3.9
# 4.1
# 4.0
# 3.9
# 4.0

# %%
d = {'CompanyName':name,'Ratings':ratings}

df = pd.DataFrame(d)

print(df)
# Out:
#                 CompanyName Ratings
# 0                       TCS     3.8
# 1                 Accenture     4.0
# 2                 Cognizant     3.9
# 3                     Wipro     3.8
# 4                 HDFC Bank     3.9
# 5                ICICI Bank     4.0
# 6                   Infosys     3.8
# 7                 Capgemini     3.8
# 8                   HCLTech     3.7
# 9             Tech Mahindra     3.7
# 10                  Genpact     3.9
# 11                Axis Bank     3.8
# 12   Concentrix Corporation     3.9
# 13                   Amazon     4.1
# 14          Teleperformance     3.6
# 15             Reliance Jio     3.9
# 16                      IBM     4.1
# 17  Larsen & Toubro Limited     4.0
# 18          Reliance Retail     3.9
# 19   HDB Financial Services     4.0

# %%
final = pd.DataFrame()

for j in range(1,11):
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
    webpage = requests.get(url,headers=headers).text
    
    soup = BeautifulSoup(webpage,'lxml')
    company = soup.find_all('div',class_= 'companyListing__cardsContainer')
    
    name = []
    ratings = []
    reviews = []
    for i in company:
        name.append(i.find('h2').text.strip())
        ratings.append(i.find_all('span',class_='companyCardWrapper__companyRatingValue')[0].text.strip())
        reviews.append(i.find('a',class_='companyCardWrapper__ActionWrapper').text)
        
    d = {'CompanyName':name,'Ratings':ratings,'Reviews':reviews}

    df = pd.DataFrame(d)
    final = final.append(df,ignore_index=True)
# Out:
# C:\Users\Roshan B\AppData\Local\Temp\ipykernel_10628\4260954844.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final = final.append(df,ignore_index=True)

# %%
final
# Out:
#                        CompanyName Ratings        Reviews
# 0                              TCS     3.8  70.5k Reviews
# 1                    Vodafone Idea     4.2    15k Reviews
# 2                    Bajaj Finserv     4.0     7k Reviews
# 3  ICICI Prudential Life Insurance     4.1   5.5k Reviews
# 4    Sun Pharmaceutical Industries     4.1   4.4k Reviews
# 5                 Omega Healthcare     3.8     4k Reviews
# 6                              UST     3.9   3.5k Reviews
# 7                     Future Group     4.3   3.2k Reviews
# 8            Intas Pharmaceuticals     4.2   2.9k Reviews
# 9  Automatic Data Processing (ADP)     4.1   2.6k Reviews

# %%
final.shape
# Out:
# (10, 3)

# %%
c = soup.find_all('div',class_='companyListing__cardsContainer')

print(c)
# Out:
# [<div class="companyListing__cardsContainer"><div itemscope="itemscope" itemtype="http://schema.org/ItemList"><meta content="20" itemprop="numberOfItems"/> <meta content="List of companies in India" itemprop="name"/> <meta content="https://www.ambitionbox.com/list-of-companies?page=10" itemprop="url"/> <div><div class="companyCardWrapper" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/> <meta content="Automatic Data Processing (ADP)" itemprop="name"/> <meta content="ADP Solutions" itemprop="alternateName"/> <meta content="https://www.ambitionbox.com/overview/adp-solutions-overview" itemprop="url"/> <meta content="https://static.ambitionbox.com/alpha/company/photos/logos/adp-solutions.jpg" itemprop="image"/> <div class="companyCardWrapper__primaryInformation"><div class="companyCardWrapper__companyDetails"><div class="companyCardWrapper__companyLogo"><img alt="ADP Solutions logo" height="50" loading="lazy" o
# ...

# %%
for i in c:
    print(i.find('a',class_='companyCardWrapper__ActionWrapper').text)
# Out:
# 2.6k Reviews

# %%
c1 = soup.find_all('div',class_= 'companyListing__cardsContainer')
print(c1)
# Out:
# [<div class="companyListing__cardsContainer"><div itemscope="itemscope" itemtype="http://schema.org/ItemList"><meta content="20" itemprop="numberOfItems"/> <meta content="List of companies in India" itemprop="name"/> <meta content="https://www.ambitionbox.com/list-of-companies?page=10" itemprop="url"/> <div><div class="companyCardWrapper" itemprop="itemListElement" itemscope="itemscope" itemtype="http://schema.org/ListItem"><meta content="1" itemprop="position"/> <meta content="Automatic Data Processing (ADP)" itemprop="name"/> <meta content="ADP Solutions" itemprop="alternateName"/> <meta content="https://www.ambitionbox.com/overview/adp-solutions-overview" itemprop="url"/> <meta content="https://static.ambitionbox.com/alpha/company/photos/logos/adp-solutions.jpg" itemprop="image"/> <div class="companyCardWrapper__primaryInformation"><div class="companyCardWrapper__companyDetails"><div class="companyCardWrapper__companyLogo"><img alt="ADP Solutions logo" height="50" loading="lazy" o
# ...

# %%
import requests

url = requests.get("https://timesofindia.indiatimes.com/city/delhi")
print(url.text)
# Out:
# <!doctype html><html class="no-js" lang="en"><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><title>Delhi News: दिल्ली समाचार - Latest Delhi News Headlines &amp; Live Updates from Delhi - Times of India</title><meta name="description" content="दिल्ली Delhi News - TOI brings the latest Delhi news headlines about Delhi crime, Delhi education news, Delhi real estate news, Delhi politics and Live Updates on local Delhi news from Times of India"/><meta name="keywords" content="Delhi, Delhi news, Delhi news live,news of Delhi, Delhi india, Delhi online, Delhi news today, Delhi India,news, Delhi,latest news, Delhi local news, Delhi headlines, Delhi news updates,Delhi city"/><link rel="canonical" href="https://timesofindia.indiatimes.com/city/delhi"/><meta property="og:title" content="Delhi News: दिल्ली समाचार - Latest Delhi News Headlines &amp; Live Updates from Delhi - T
# ...
