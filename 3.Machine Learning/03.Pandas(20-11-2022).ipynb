# %%
# operations on data

import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\DS_data_set_analysis.csv")

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df['new_cases_smoothed'].fillna(17)
# Out:
# 0        17.000
# 1        17.000
# 2        17.000
# 3        17.000
# 4        17.000
#           ...
# 94862    35.000
# 94863    39.571
# 94864    46.143
# 94865    57.286
# 94866    57.714
# Name: new_cases_smoothed, Length: 94867, dtype: float64

# %%
df1 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv")

# %%
df1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# sorting data

df1.sort_index(axis=1)   # sorting to column   for column, axis = 1
# Out:
#                                            actors_list content_rating  \
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              R
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              R
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              R
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...          PG-13
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              R
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...             PG
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...             PG
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...          PG-13
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...             PG
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              R
#
#      duration      genre  star_rating  \
# 0         142      Crime          9.3
# 1         175      Crime          9.2
# ...

# %%
df1.sort_index(axis=0)   # sorting to row (mostly not used)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.sort_index(ascending=False)   # sorting by index, descending order
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# ...        ...       ...          ...         ...          ...        ...
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.sort_index(ascending=True)   # sorting by index, ascending order
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.sort_values(['location'],ascending=False)  # sorting to particular column('location)', descending order
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
# 94642      ZWE    Africa     Zimbabwe  29/10/2020       8349.0       29.0
# 94560      ZWE    Africa     Zimbabwe  08/08/2020       4575.0      124.0
# 94561      ZWE    Africa     Zimbabwe  09/08/2020       4649.0       74.0
# 94562      ZWE    Africa     Zimbabwe  10/08/2020       4748.0       99.0
# ...        ...       ...          ...         ...          ...        ...
# 320        AFG      Asia  Afghanistan  09/01/2021      53400.0       68.0
# 321        AFG      Asia  Afghanistan  10/01/2021      53489.0       89.0
# 322        AFG      Asia  Afghanistan  11/01/2021      53538.0       49.0
# 323        AFG      Asia  Afghanistan  12/01/2021      53584.0       46.0
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.sort_values(['iso_code'],ascending=True)   # sorting to particular column('iso_code)', ascending order
# Out:
#       iso_code      continent  location        date  total_cases  new_cases  \
# 4444       ABW  North America     Aruba  27/05/2021          NaN        NaN
# 4437       ABW  North America     Aruba  20/05/2021          NaN        NaN
# 4436       ABW  North America     Aruba  19/05/2021          NaN        NaN
# 4435       ABW  North America     Aruba  18/05/2021          NaN        NaN
# 4458       ABW  North America     Aruba  10/06/2021          NaN        NaN
# ...        ...            ...       ...         ...          ...        ...
# 94561      ZWE         Africa  Zimbabwe  09/08/2020       4649.0       74.0
# 94560      ZWE         Africa  Zimbabwe  08/08/2020       4575.0      124.0
# 94559      ZWE         Africa  Zimbabwe  07/08/2020       4451.0      112.0
# 94641      ZWE         Africa  Zimbabwe  28/10/2020       8320.0        5.0
# 94866      ZWE         Africa  Zimbabwe  10/06/2021      39496.0       64.0
#
# ...

# %%
df1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df1.sort_values(['duration'])   # sorting duration column, by default ascending order
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %%
# Index

# index start from 0, use of index:- search, filter out,fetch particular record

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# index start from genre

df1 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv",index_col= 'genre')

# %%
df1
# Out:
#            star_rating                                            title  \
# genre
# Crime              9.3                         The Shawshank Redemption
# Crime              9.2                                    The Godfather
# Crime              9.1                           The Godfather: Part II
# Action             9.0                                  The Dark Knight
# Crime              8.9                                     Pulp Fiction
# ...                ...                                              ...
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
# Crime              7.4                                      Wall Street
#
#           content_rating  duration  \
# genre
# Crime                  R       142
# ...

# %%
df1
# Out:
#            star_rating                                            title  \
# genre
# Crime              9.3                         The Shawshank Redemption
# Crime              9.2                                    The Godfather
# Crime              9.1                           The Godfather: Part II
# Action             9.0                                  The Dark Knight
# Crime              8.9                                     Pulp Fiction
# ...                ...                                              ...
# Comedy             7.4                                          Tootsie
# Adventure          7.4                      Back to the Future Part III
# Action             7.4  Master and Commander: The Far Side of the World
# Horror             7.4                                      Poltergeist
# Crime              7.4                                      Wall Street
#
#           content_rating  duration  \
# genre
# Crime                  R       142
# ...

# %%
df1 = pd.read_csv(r"C:\Users\Roshan B\Desktop\ML\Dataset\movies_data.csv")

# %%
df1
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# after read set index by duration column

df1.set_index('duration',inplace=True)

# %%
df1
# Out:
#           star_rating                                            title  \
# duration
# 142               9.3                         The Shawshank Redemption
# 175               9.2                                    The Godfather
# 200               9.1                           The Godfather: Part II
# 152               9.0                                  The Dark Knight
# 154               8.9                                     Pulp Fiction
# ...               ...                                              ...
# 116               7.4                                          Tootsie
# 118               7.4                      Back to the Future Part III
# 138               7.4  Master and Commander: The Far Side of the World
# 114               7.4                                      Poltergeist
# 126               7.4                                      Wall Street
#
#          content_rating      genre  \
# duration
# 142                   R      Crime
# ...

# %%
df1.sort_index()   # ascending order to duration(it is index) (by default ascending otder)
# Out:
#           star_rating                              title content_rating  \
# duration
# 64                8.0                             Freaks        UNRATED
# 66                8.0                Battleship Potemkin        UNRATED
# 67                8.1        The Cabinet of Dr. Caligari        UNRATED
# 68                8.1                          Duck Soup         PASSED
# 68                8.4                            The Kid      NOT RATED
# ...               ...                                ...            ...
# 220               7.9               The Ten Commandments       APPROVED
# 224               8.3  Lagaan: Once Upon a Time in India             PG
# 229               8.4        Once Upon a Time in America              R
# 238               8.2                 Gone with the Wind              G
# 242               7.8                             Hamlet          PG-13
#
#               genre                                        actors_list
# duration
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      duration  star_rating                                            title  \
# 0         142          9.3                         The Shawshank Redemption
# 1         175          9.2                                    The Godfather
# 2         200          9.1                           The Godfather: Part II
# 3         152          9.0                                  The Dark Knight
# 4         154          8.9                                     Pulp Fiction
# ..        ...          ...                                              ...
# 974       116          7.4                                          Tootsie
# 975       118          7.4                      Back to the Future Part III
# 976       138          7.4  Master and Commander: The Far Side of the World
# 977       114          7.4                                      Poltergeist
# 978       126          7.4                                      Wall Street
#
#     content_rating      genre  \
# ...

# %%
df1.iloc[1]
# Out:
# duration                                                      175
# star_rating                                                   9.2
# title                                               The Godfather
# content_rating                                                  R
# genre                                                       Crime
# actors_list       [u'Marlon Brando', u'Al Pacino', u'James Caan']
# Name: 1, dtype: object

# %%
df1.set_index('duration', inplace=True)

# %%
df1
# Out:
#           star_rating                                            title  \
# duration
# 142               9.3                         The Shawshank Redemption
# 175               9.2                                    The Godfather
# 200               9.1                           The Godfather: Part II
# 152               9.0                                  The Dark Knight
# 154               8.9                                     Pulp Fiction
# ...               ...                                              ...
# 116               7.4                                          Tootsie
# 118               7.4                      Back to the Future Part III
# 138               7.4  Master and Commander: The Far Side of the World
# 114               7.4                                      Poltergeist
# 126               7.4                                      Wall Street
#
#          content_rating      genre  \
# duration
# 142                   R      Crime
# ...

# %%
df1.iloc[142]
# Out:
# star_rating                                                     8.3
# title                             Lagaan: Once Upon a Time in India
# content_rating                                                   PG
# genre                                                     Adventure
# actors_list       [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# Name: 224, dtype: object

# %%
df1.sort_index()
# Out:
#           star_rating                              title content_rating  \
# duration
# 64                8.0                             Freaks        UNRATED
# 66                8.0                Battleship Potemkin        UNRATED
# 67                8.1        The Cabinet of Dr. Caligari        UNRATED
# 68                8.1                          Duck Soup         PASSED
# 68                8.4                            The Kid      NOT RATED
# ...               ...                                ...            ...
# 220               7.9               The Ten Commandments       APPROVED
# 224               8.3  Lagaan: Once Upon a Time in India             PG
# 229               8.4        Once Upon a Time in America              R
# 238               8.2                 Gone with the Wind              G
# 242               7.8                             Hamlet          PG-13
#
#               genre                                        actors_list
# duration
# ...

# %%
df1.iloc[64]
# Out:
# star_rating                                                    8.4
# title                                                       WALL-E
# content_rating                                                   G
# genre                                                    Animation
# actors_list       [u'Ben Burtt', u'Elissa Knight', u'Jeff Garlin']
# Name: 98, dtype: object

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      duration  star_rating                                            title  \
# 0         142          9.3                         The Shawshank Redemption
# 1         175          9.2                                    The Godfather
# 2         200          9.1                           The Godfather: Part II
# 3         152          9.0                                  The Dark Knight
# 4         154          8.9                                     Pulp Fiction
# ..        ...          ...                                              ...
# 974       116          7.4                                          Tootsie
# 975       118          7.4                      Back to the Future Part III
# 976       138          7.4  Master and Commander: The Far Side of the World
# 977       114          7.4                                      Poltergeist
# 978       126          7.4                                      Wall Street
#
#     content_rating      genre  \
# ...

# %%
df1.iloc[64]
# Out:
# duration                                                        98
# star_rating                                                    8.4
# title                                                       WALL-E
# content_rating                                                   G
# genre                                                    Animation
# actors_list       [u'Ben Burtt', u'Elissa Knight', u'Jeff Garlin']
# Name: 64, dtype: object

# %%
# for single column drop,     for   rows == axis = 0
                          #   for   col == axis = 1

# %%
df1.drop('star_rating',axis=1,inplace=True)    # here drop 'star_rating' column, if axis not mention so by default axis = 0, i.e(Row)

# %%
df1
# Out:
#      duration                                            title content_rating  \
# 0         142                         The Shawshank Redemption              R
# 1         175                                    The Godfather              R
# 2         200                           The Godfather: Part II              R
# 3         152                                  The Dark Knight          PG-13
# 4         154                                     Pulp Fiction              R
# ..        ...                                              ...            ...
# 974       116                                          Tootsie             PG
# 975       118                      Back to the Future Part III             PG
# 976       138  Master and Commander: The Far Side of the World          PG-13
# 977       114                                      Poltergeist             PG
# 978       126                                      Wall Street              R
#
# ...

# %%
# drop multiple column at a time

df1.drop(columns=['actors_list','title'],inplace=True)

# %%
df1
# Out:
#      duration content_rating      genre
# 0         142              R      Crime
# 1         175              R      Crime
# 2         200              R      Crime
# 3         152          PG-13     Action
# 4         154              R      Crime
# ..        ...            ...        ...
# 974       116             PG     Comedy
# 975       118             PG  Adventure
# 976       138          PG-13     Action
# 977       114             PG     Horror
# 978       126              R      Crime
#
# [979 rows x 3 columns]

# %%
df1
# Out:
#      duration content_rating      genre
# 0         142              R      Crime
# 1         175              R      Crime
# 2         200              R      Crime
# 3         152          PG-13     Action
# 4         154              R      Crime
# ..        ...            ...        ...
# 974       116             PG     Comedy
# 975       118             PG  Adventure
# 976       138          PG-13     Action
# 977       114             PG     Horror
# 978       126              R      Crime
#
# [979 rows x 3 columns]

# %%
df1.isnull().sum()   # to check total null values
# Out:
# duration          0
# content_rating    3
# genre             0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# duration          0
# content_rating    3
# genre             0
# dtype: int64

# %%
# drop rows where null values

df1.dropna()
# Out:
#      duration content_rating      genre
# 0         142              R      Crime
# 1         175              R      Crime
# 2         200              R      Crime
# 3         152          PG-13     Action
# 4         154              R      Crime
# ..        ...            ...        ...
# 974       116             PG     Comedy
# 975       118             PG  Adventure
# 976       138          PG-13     Action
# 977       114             PG     Horror
# 978       126              R      Crime
#
# [976 rows x 3 columns]

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 94862      ZWE    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863      ZWE    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864      ZWE    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865      ZWE    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866      ZWE    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df2 = df.set_index('continent')

# %%
df2
# Out:
#           iso_code     location        date  total_cases  new_cases  \
# continent
# Asia           AFG  Afghanistan  24/02/2020          1.0        1.0
# Asia           AFG  Afghanistan  25/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  26/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  27/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  28/02/2020          1.0        0.0
# ...            ...          ...         ...          ...        ...
# Africa         ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# Africa         ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# Africa         ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# Africa         ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# Africa         ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#            new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# continent
# ...

# %%
df2.drop('Africa')
# Out:
#           iso_code     location        date  total_cases  new_cases  \
# continent
# Asia           AFG  Afghanistan  24/02/2020          1.0        1.0
# Asia           AFG  Afghanistan  25/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  26/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  27/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  28/02/2020          1.0        0.0
# ...            ...          ...         ...          ...        ...
# Asia           YEM        Yemen  06/06/2021       6787.0        7.0
# Asia           YEM        Yemen  07/06/2021       6812.0       25.0
# Asia           YEM        Yemen  08/06/2021       6823.0       11.0
# Asia           YEM        Yemen  09/06/2021       6832.0        9.0
# Asia           YEM        Yemen  10/06/2021       6836.0        4.0
#
#            new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# continent
# ...

# %%
df2.value_counts
# Out:
# <bound method DataFrame.value_counts of           iso_code     location        date  total_cases  new_cases  \
# continent
# Asia           AFG  Afghanistan  24/02/2020          1.0        1.0
# Asia           AFG  Afghanistan  25/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  26/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  27/02/2020          1.0        0.0
# Asia           AFG  Afghanistan  28/02/2020          1.0        0.0
# ...            ...          ...         ...          ...        ...
# Africa         ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# Africa         ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# Africa         ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# Africa         ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# Africa         ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#            new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# continent
# ...

# %%
df2.reset_index()
# Out:
#       continent iso_code     location        date  total_cases  new_cases  \
# 0          Asia      AFG  Afghanistan  24/02/2020          1.0        1.0
# 1          Asia      AFG  Afghanistan  25/02/2020          1.0        0.0
# 2          Asia      AFG  Afghanistan  26/02/2020          1.0        0.0
# 3          Asia      AFG  Afghanistan  27/02/2020          1.0        0.0
# 4          Asia      AFG  Afghanistan  28/02/2020          1.0        0.0
# ...         ...      ...          ...         ...          ...        ...
# 94862    Africa      ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# 94863    Africa      ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# 94864    Africa      ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# 94865    Africa      ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# 94866    Africa      ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df2['iso_code'].unique()
# Out:
# array(['AFG', 'OWID_AFR', 'ALB', 'DZA', 'AND', 'AGO', 'AIA', 'ATG', 'ARG',
#        'ARM', 'ABW', 'OWID_ASI', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD',
#        'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BES',
#        'BIH', 'BWA', 'BRA', 'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'KHM',
#        'CMR', 'CAN', 'CPV', 'CYM', 'CAF', 'TCD', 'CHL', 'CHN', 'COL',
#        'COM', 'COG', 'COK', 'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP',
#        'CZE', 'COD', 'DNK', 'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV',
#        'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'OWID_EUR', 'OWID_EUN', 'FRO',
#        'FLK', 'FJI', 'FIN', 'FRA', 'PYF', 'GAB', 'GMB', 'GEO', 'DEU',
#        'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GTM', 'GGY', 'GIN', 'GNB',
#        'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND', 'IDN', 'OWID_INT',
#        'IRN', 'IRQ', 'IRL', 'IMN', 'ISR', 'ITA', 'JAM', 'JPN', 'JEY',
#        'JOR', 'KAZ', 'KEN', 'KIR', 'OWID_KOS', 'KWT', 'KGZ', 'LAO', 'LVA',
# ...

# %%
df['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
# loc & iloc---->(iloc = integer loc)

'''
lock = name
iloc = integer location
'''
# how to use

# loc = [row:column:step]     [row_start:row_end,col_start:col_end]
# iloc = [row:column:step]
# Out:
# '\nlock = name\niloc = integer location\n'

# %%
py_dict = {
    'id':[10,11,12,13,14],
    'name':['Roshan','Asha','Mohan','Ganesh','Jayesh'],
    'city':['Pune','Mumbai','Goa','Delhi','Nagpur'],
    'salary':[95800,56140,78540,65800,65900]
}

# %%
df3 = pd.DataFrame(py_dict)
df3
# Out:
#    id    name    city  salary
# 0  10  Roshan    Pune   95800
# 1  11    Asha  Mumbai   56140
# 2  12   Mohan     Goa   78540
# 3  13  Ganesh   Delhi   65800
# 4  14  Jayesh  Nagpur   65900

# %%
df3
# Out:
#    id    name    city  salary
# 0  10  Roshan    Pune   95800
# 1  11    Asha  Mumbai   56140
# 2  12   Mohan     Goa   78540
# 3  13  Ganesh   Delhi   65800
# 4  14  Jayesh  Nagpur   65900

# %%
# loc  ( it is used for name location)

# Note : stop index inclusive,   imp

# %%
df3.loc[[2,3],['name','salary']]
# Out:
#      name  salary
# 2   Mohan   78540
# 3  Ganesh   65800

# %%
df3.loc[:,['name','city']]
# Out:
#      name    city
# 0  Roshan    Pune
# 1    Asha  Mumbai
# 2   Mohan     Goa
# 3  Ganesh   Delhi
# 4  Jayesh  Nagpur

# %%
df3.loc[1:3:2,'id':'city':2]
# Out:
#    id    city
# 1  11  Mumbai
# 3  13   Delhi

# %%
df3.loc[::2,::2]
# Out:
#    id    city
# 0  10    Pune
# 2  12     Goa
# 4  14  Nagpur

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df3
# Out:
#    id    name    city  salary
# 0  10  Roshan    Pune   95800
# 1  11    Asha  Mumbai   56140
# 2  12   Mohan     Goa   78540
# 3  13  Ganesh   Delhi   65800
# 4  14  Jayesh  Nagpur   65900

# %%
df3.loc[[i for i in df3.index%2==0]]   # even index
# Out:
#    id    name    city  salary
# 0  10  Roshan    Pune   95800
# 2  12   Mohan     Goa   78540
# 4  14  Jayesh  Nagpur   65900

# %%
df3[df3['salary']>70000]     # fetch record for salary greater than 70000
# Out:
#    id    name  city  salary
# 0  10  Roshan  Pune   95800
# 2  12   Mohan   Goa   78540

# %%
df3.loc[[1,3]]
# Out:
#    id    name    city  salary
# 1  11    Asha  Mumbai   56140
# 3  13  Ganesh   Delhi   65800

# %%
# iloc  ( it is used for integer location)

# Note : stop index exclusive, imp

# %%
df3.iloc[1:3]
# Out:
#    id   name    city  salary
# 1  11   Asha  Mumbai   56140
# 2  12  Mohan     Goa   78540

# %%
df3.iloc[0:3,0:2]
# Out:
#    id    name
# 0  10  Roshan
# 1  11    Asha
# 2  12   Mohan

# %%
df2.reset_index(inplace = True)

# %%
df2
# Out:
#       continent iso_code     location        date  total_cases  new_cases  \
# 0          Asia      AFG  Afghanistan  24/02/2020          1.0        1.0
# 1          Asia      AFG  Afghanistan  25/02/2020          1.0        0.0
# 2          Asia      AFG  Afghanistan  26/02/2020          1.0        0.0
# 3          Asia      AFG  Afghanistan  27/02/2020          1.0        0.0
# 4          Asia      AFG  Afghanistan  28/02/2020          1.0        0.0
# ...         ...      ...          ...         ...          ...        ...
# 94862    Africa      ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# 94863    Africa      ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# 94864    Africa      ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# 94865    Africa      ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# 94866    Africa      ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df2.loc[1:10,'continent':'total_cases']
# Out:
#    continent iso_code     location        date  total_cases
# 1       Asia      AFG  Afghanistan  25/02/2020          1.0
# 2       Asia      AFG  Afghanistan  26/02/2020          1.0
# 3       Asia      AFG  Afghanistan  27/02/2020          1.0
# 4       Asia      AFG  Afghanistan  28/02/2020          1.0
# 5       Asia      AFG  Afghanistan  29/02/2020          1.0
# 6       Asia      AFG  Afghanistan  01/03/2020          1.0
# 7       Asia      AFG  Afghanistan  02/03/2020          1.0
# 8       Asia      AFG  Afghanistan  03/03/2020          2.0
# 9       Asia      AFG  Afghanistan  04/03/2020          4.0
# 10      Asia      AFG  Afghanistan  05/03/2020          4.0

# %%
df2.loc[[1,5,6,9,10],::2]
# Out:
#    continent     location  total_cases  new_cases_smoothed  new_deaths  \
# 1       Asia  Afghanistan          1.0                 NaN         NaN
# 5       Asia  Afghanistan          1.0               0.143         NaN
# 6       Asia  Afghanistan          1.0               0.143         NaN
# 9       Asia  Afghanistan          4.0               0.429         NaN
# 10      Asia  Afghanistan          4.0               0.429         NaN
#
#     total_cases_per_million  new_cases_smoothed_per_million  \
# 1                     0.026                             NaN
# 5                     0.026                           0.004
# 6                     0.026                           0.004
# 9                     0.103                           0.011
# 10                    0.103                           0.011
#
#     new_deaths_per_million  reproduction_rate  icu_patients_per_million  ...  \
# 1                      NaN                NaN                       NaN  ...
# ...

# %%
df2.iloc[1:15,1:10]
# Out:
#    iso_code     location        date  total_cases  new_cases  \
# 1       AFG  Afghanistan  25/02/2020          1.0        0.0
# 2       AFG  Afghanistan  26/02/2020          1.0        0.0
# 3       AFG  Afghanistan  27/02/2020          1.0        0.0
# 4       AFG  Afghanistan  28/02/2020          1.0        0.0
# 5       AFG  Afghanistan  29/02/2020          1.0        0.0
# 6       AFG  Afghanistan  01/03/2020          1.0        0.0
# 7       AFG  Afghanistan  02/03/2020          1.0        0.0
# 8       AFG  Afghanistan  03/03/2020          2.0        1.0
# 9       AFG  Afghanistan  04/03/2020          4.0        2.0
# 10      AFG  Afghanistan  05/03/2020          4.0        0.0
# 11      AFG  Afghanistan  06/03/2020          4.0        0.0
# 12      AFG  Afghanistan  07/03/2020          4.0        0.0
# 13      AFG  Afghanistan  08/03/2020          5.0        1.0
# 14      AFG  Afghanistan  09/03/2020          7.0        2.0
#
# ...

# %%
'''
1. Selecting Columns : [ ] operator, loc, iloc
2. Filtering Rows : [ ] operator, loc, iloc, isin, query, between, string methods
3. Updating Values : loc, iloc, replace
'''

# %%
import pandas as pd

# %%
df2
# Out:
#       continent iso_code     location        date  total_cases  new_cases  \
# 0          Asia      AFG  Afghanistan  24/02/2020          1.0        1.0
# 1          Asia      AFG  Afghanistan  25/02/2020          1.0        0.0
# 2          Asia      AFG  Afghanistan  26/02/2020          1.0        0.0
# 3          Asia      AFG  Afghanistan  27/02/2020          1.0        0.0
# 4          Asia      AFG  Afghanistan  28/02/2020          1.0        0.0
# ...         ...      ...          ...         ...          ...        ...
# 94862    Africa      ZWE     Zimbabwe  06/06/2021      39189.0       21.0
# 94863    Africa      ZWE     Zimbabwe  07/06/2021      39238.0       49.0
# 94864    Africa      ZWE     Zimbabwe  08/06/2021      39321.0       83.0
# 94865    Africa      ZWE     Zimbabwe  09/06/2021      39432.0      111.0
# 94866    Africa      ZWE     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# loc:-

# 1. loc :- this accessor selects rows and columns by labels

# ex. df.loc[row_labels,column_labels]
'''
df.loc['row1_label:row2_label','column1_label:column2_laabel']
'''
# Out:
# "\ndf['row1_label:row2_label','column1_label:column2_laabel']\n"

# %%
# using loc for label-based selection

df.loc[:,'continent':'new_deaths']  # fetch all row and column from "continent" to "new_deaths"
# Out:
#       continent     location        date  total_cases  new_cases  \
# 0          Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          Asia  Afghanistan  28/02/2020          1.0        0.0
# ...         ...          ...         ...          ...        ...
# 94862    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94863    Africa     Zimbabwe  07/06/2021      39238.0       49.0
# 94864    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94865    Africa     Zimbabwe  09/06/2021      39432.0      111.0
# 94866    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
#        new_cases_smoothed  total_deaths  new_deaths
# 0                     NaN           NaN         NaN
# 1                     NaN           NaN         NaN
# ...

# %%
df.loc[1:50,:] # data fetch row from 1 to 50 and all columns
# Out:
#    iso_code continent     location        date  total_cases  new_cases  \
# 1       AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2       AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3       AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4       AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# 5       AFG      Asia  Afghanistan  29/02/2020          1.0        0.0
# 6       AFG      Asia  Afghanistan  01/03/2020          1.0        0.0
# 7       AFG      Asia  Afghanistan  02/03/2020          1.0        0.0
# 8       AFG      Asia  Afghanistan  03/03/2020          2.0        1.0
# 9       AFG      Asia  Afghanistan  04/03/2020          4.0        2.0
# 10      AFG      Asia  Afghanistan  05/03/2020          4.0        0.0
# 11      AFG      Asia  Afghanistan  06/03/2020          4.0        0.0
# 12      AFG      Asia  Afghanistan  07/03/2020          4.0        0.0
# ...

# %%
df.loc[1:10,'continent':'new_deaths']  # data fetch from row 1 to 10 and column from "continent" to 'new_deaths'
# Out:
#    continent     location        date  total_cases  new_cases  \
# 1       Asia  Afghanistan  25/02/2020          1.0        0.0
# 2       Asia  Afghanistan  26/02/2020          1.0        0.0
# 3       Asia  Afghanistan  27/02/2020          1.0        0.0
# 4       Asia  Afghanistan  28/02/2020          1.0        0.0
# 5       Asia  Afghanistan  29/02/2020          1.0        0.0
# 6       Asia  Afghanistan  01/03/2020          1.0        0.0
# 7       Asia  Afghanistan  02/03/2020          1.0        0.0
# 8       Asia  Afghanistan  03/03/2020          2.0        1.0
# 9       Asia  Afghanistan  04/03/2020          4.0        2.0
# 10      Asia  Afghanistan  05/03/2020          4.0        0.0
#
#     new_cases_smoothed  total_deaths  new_deaths
# 1                  NaN           NaN         NaN
# 2                  NaN           NaN         NaN
# 3                  NaN           NaN         NaN
# 4                  NaN           NaN         NaN
# ...

# %%
df.loc[[1,4,6],'continent':'new_cases']
# Out:
#   continent     location        date  total_cases  new_cases
# 1      Asia  Afghanistan  25/02/2020          1.0        0.0
# 4      Asia  Afghanistan  28/02/2020          1.0        0.0
# 6      Asia  Afghanistan  01/03/2020          1.0        0.0

# %%
df.loc[[i for i in df.index if i%2==0],'continent':'new_cases']
# Out:
#       continent     location        date  total_cases  new_cases
# 0          Asia  Afghanistan  24/02/2020          1.0        1.0
# 2          Asia  Afghanistan  26/02/2020          1.0        0.0
# 4          Asia  Afghanistan  28/02/2020          1.0        0.0
# 6          Asia  Afghanistan  01/03/2020          1.0        0.0
# 8          Asia  Afghanistan  03/03/2020          2.0        1.0
# ...         ...          ...         ...          ...        ...
# 94858    Africa     Zimbabwe  02/06/2021      39031.0       33.0
# 94860    Africa     Zimbabwe  04/06/2021      39144.0       52.0
# 94862    Africa     Zimbabwe  06/06/2021      39189.0       21.0
# 94864    Africa     Zimbabwe  08/06/2021      39321.0       83.0
# 94866    Africa     Zimbabwe  10/06/2021      39496.0       64.0
#
# [47434 rows x 5 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=94867, step=1)

# %%
df.loc[[1,5,7,8],['continent','location','new_cases']]
# Out:
#   continent     location  new_cases
# 1      Asia  Afghanistan        0.0
# 5      Asia  Afghanistan        0.0
# 7      Asia  Afghanistan        0.0
# 8      Asia  Afghanistan        1.0

# %%
df.loc[[i for i in df.index if i%1000==0],['continent','location','total_deaths']]
# Out:
#            continent             location  total_deaths
# 0               Asia          Afghanistan           NaN
# 1000          Europe              Albania          22.0
# 2000          Europe              Andorra          51.0
# 3000   North America  Antigua and Barbuda           3.0
# 4000            Asia              Armenia          74.0
# ...              ...                  ...           ...
# 90000  North America        United States       47715.0
# 91000           Asia           Uzbekistan          98.0
# 92000  South America            Venezuela           NaN
# 93000        Oceania    Wallis and Futuna           NaN
# 94000         Africa               Zambia           2.0
#
# [95 rows x 3 columns]

# %%
# iloc:-

# 1. iloc :- this accessor selects rows and columns by integer location.

# ex. df.iloc[row_position,column_position]
'''
df.iloc['row1_position:row2_position','column1_position:column2_position']
'''

# %%
# using loc for index-based selection

df.iloc[[0,1,2,3],[3,4,5,6]]  # fetch row 0,1,2,3 and column index number 3,4,5,6
# Out:
#          date  total_cases  new_cases  new_cases_smoothed
# 0  24/02/2020          1.0        1.0                 NaN
# 1  25/02/2020          1.0        0.0                 NaN
# 2  26/02/2020          1.0        0.0                 NaN
# 3  27/02/2020          1.0        0.0                 NaN

# %%
df.iloc[1:10,0:5]  # fecth row from 1 to 9 and column from 0 to 4, (end is exlusive in iloc for row and column)
# Out:
#   iso_code continent     location        date  total_cases
# 1      AFG      Asia  Afghanistan  25/02/2020          1.0
# 2      AFG      Asia  Afghanistan  26/02/2020          1.0
# 3      AFG      Asia  Afghanistan  27/02/2020          1.0
# 4      AFG      Asia  Afghanistan  28/02/2020          1.0
# 5      AFG      Asia  Afghanistan  29/02/2020          1.0
# 6      AFG      Asia  Afghanistan  01/03/2020          1.0
# 7      AFG      Asia  Afghanistan  02/03/2020          1.0
# 8      AFG      Asia  Afghanistan  03/03/2020          2.0
# 9      AFG      Asia  Afghanistan  04/03/2020          4.0
